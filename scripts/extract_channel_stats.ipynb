# %%
import csv
import urllib.request as urllib2
from lxml import html, etree
import json
import numpy as np
import pandas as pd

api_key = 'AIzaSyCrFWiPfGcb5IsyS-wpAMk6eaNdMaC8pXs'
channel = 'UChUEb7Fczc6jyXo-R0qnn8Q'
vidStats =  'https://www.googleapis.com/youtube/v3/videos?part=id,statistics&id='
vidSnips = 'https://www.googleapis.com/youtube/v3/videos?part=id,snippet&id='
channelStats = 'https://www.googleapis.com/youtube/v3/channels?part=snippet,statistics&id='

df = pd.read_csv('../data/cleaned_subset.csv',encoding = 'latin-1')

# %%
df.head()
# Out:
#             Id                                              Title  \
# 0  AUzyaHo0QQc     b'300 pushups a day for 20 days!! - Results!!'
# 1  1Zgtdb7jp60                                 b'John Cena - gym'
# 2  1Sfii7rnkJQ      b'Bodybuilding Motivation - No Time To Waste'
# 3  UUwSKJjx9Go  b'Most Powerful Home Chest Workout Ever : Buil...
# 4  Yl3NGvna2KA  b'Greg Plitt Best of The Best Workout Video Pr...
#
#                                          Description  LikeCount  DislikeCount  \
# 0  b'**NEW** (2016) Abs Workout for 30 Days | htt...      40408         10312
# 1  b"Follow John Cena on twitter: http://www.twit...      37867          1486
# 2  b"Follow me:\nhttp://instagram.com/shaqx.bb\nh...      17688          1291
# 3  b'http://www.6weeksixpack.com This is one of t...      46293          2589
# 4  b'SIGN UP TODAY - http://bit.ly/jointheranks\r...      24784          1134
#
#    ViewCount  FavoriteCount  CommentCount               PublishedAt  \
# ...

# %%
channelInfo = df['Channel Id']

# %%
channelInfo = list(set(channelInfo))

# %%
firstTime = True
with open('../data/channelStats.csv', 'a',newline='') as c:

    writer = csv.writer(c)
    
    if firstTime:
        writer.writerow(['Channel Id', 
                     'publishedAt', 
                     'subscriberCount', 
                     'channelVideoCount', 
                     'channelViewCount', 
                     ])
    counter = 0
    for channel in channelInfo:
        stats = json.load(urllib2.urlopen(channelStats + channel + '&key=' + api_key))
        
        writer.writerow([channel, 
                         stats['items'][0]['snippet']['publishedAt'],
                        stats['items'][0]['statistics']['subscriberCount'],
                         stats['items'][0]['statistics']['videoCount'],
                         stats['items'][0]['statistics']['viewCount']
                                                       ])
        counter +=1
        if(counter % 5 ==0):
            print("Progess: " + str(counter))
print("Done!")
# Out:
# Progess: 5
# Progess: 10
# Progess: 15
# Progess: 20
# Progess: 25
# Progess: 30
# Progess: 35
# Progess: 40
# Progess: 45
# Progess: 50
# Progess: 55
# Progess: 60
# Progess: 65
# Progess: 70
# Progess: 75
# Progess: 80
# Progess: 85
# Progess: 90
# Progess: 95
# Progess: 100
# Progess: 105
# Progess: 110
# Progess: 115
# Progess: 120
# Progess: 125
# Progess: 130
# Progess: 135
# Progess: 140
# Progess: 145
# Progess: 150
# Progess: 155
# Progess: 160
# Progess: 165
# Progess: 170
# Progess: 175
# Progess: 180
# Progess: 185
# Progess: 190
# Progess: 195
# Progess: 200
# Progess: 205
# Progess: 210
# Progess: 215
# Progess: 220
# Progess: 225
# Progess: 230
# Progess: 235
# Progess: 240
# Progess: 245
# Progess: 250
# Progess: 255
# Progess: 260
# Progess: 265
# Progess: 270
# Progess: 275
# Progess: 280
# Progess: 285
# Progess: 290
# Progess: 295
# Progess: 300
# Progess: 305
# Progess: 310
# Progess: 315
# Progess: 320
# Progess: 325
# Progess: 330
# Progess: 335
# Progess: 340
# ...

# %%
for channel in channelInfo:
    stats = json.load(urllib2.urlopen(channelStats + channel + '&key=' + api_key))

# %%
stats = json.load(urllib2.urlopen(channelStats + channel + '&key=' + api_key))

# %%
stats
# Out:
# {'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/LQrJypwTRKWW03QpdW-dzqyB88Y"',
#  'items': [{'etag': '"ld9biNPKjAjgjV7EZ4EKeEGrhao/xKKv47AxhzezJC2f-a5EDuIN8_o"',
#    'id': 'UChUEb7Fczc6jyXo-R0qnn8Q',
#    'kind': 'youtube#channel',
#    'snippet': {'country': 'US',
# ...

# %%
stats['items'][0]['snippet']
# Out:
# {'country': 'US',
#  'description': 'My name is Nikki Blackketter! I live in Los Angeles, California and a short human, a total kid at heart. I make (somewhat) daily vlogs that are mostly about fitness & weight lifting workouts and adventures with my roommate, friends, boyfriend, family, and cat / feline companion. They show how I balance being young, having fun, and being in a healthy relationship, with working out and making sure my diet and health is on point to keep a nice, toned figure. \nGlute / booty & leg lifts are my specialty. :) \nI also enjoy video games, Game of Thrones, Star Wars, and have some stormtrooper friends. Gets pretty wild over here, lol.\nPlease subscribe to keep up!\n\nFollow me on \nSnapchat: nblackketter\nInstagram @nikkiblackketter\nFacebook: facebook.com/nikki.blackketter\nTwitter @itsnikkib\n\nMy website: www.nikkiblackketter.com',
# ...

# %%
stats['items'][0]['statistics']
# Out:
# {'commentCount': '0',
#  'hiddenSubscriberCount': False,
#  'subscriberCount': '613548',
#  'videoCount': '435',
#  'viewCount': '85697881'}

# %%
stats['items'][0]['snippet']['publishedAt']
# Out:
# '2014-01-17T18:56:04.000Z'
