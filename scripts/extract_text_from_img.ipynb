# %%
import os
import requests # pip install requests
import numpy as np
import pandas as pd
from IPython.display import YouTubeVideo


ROOT_DIR = os.path.dirname(os.path.realpath('__file__'))
DATA_PATH = os.path.join(ROOT_DIR, '..', 'data')

script_path = os.path.join(DATA_PATH, 'cleaned_subset.csv')


df = pd.read_csv(script_path)

print ('Total: {0} images'.format(df.shape[0]))
# Out:
# Total: 10682 images

# %%
YouTubeVideo('54krdTEyziQ')

# %%
df = df[:4000]
df.shape[0]
df['ImageText'] = ''
df['ContainsText'] = ''

# %%
########### Python 2.7 #############
import httplib, urllib, base64, json, re, time

###############################################
#### Update or verify the following values. ###
###############################################

# Replace the subscription_key string value with your valid subscription key.
subscription_key = '99111d8302ee4f60a5d8b114abdf531f'

# Replace or verify the region.
#
# You must use the same region in your REST API call as you used to obtain your subscription keys.
# For example, if you obtained your subscription keys from the westus region, replace
# "westcentralus" in the URI below with "westus".
#
# NOTE: Free trial subscription keys are generated in the westcentralus region, so if you are using
# a free trial subscription key, you should not need to change this region.
uri_base = 'westcentralus.api.cognitive.microsoft.com'

headers = {
    # Request headers.
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': subscription_key,
}

params = urllib.urlencode({
    # Request parameters. The language setting "unk" means automatically detect the language.
    'language': 'unk',
    'detectOrientation ': 'true',
})


for index, row in df.iterrows():
    link = re.findall(r"'(.*?)'",df['Thumbnail Default'][index])[0]  
    # The URL of a JPEG image containing text.
    body = "{'url':" + "'" + link + "'" + "}"
    print body
    try:
        # Execute the REST API call and get the response.
        conn = httplib.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
        conn.request("POST", "/vision/v1.0/ocr?%s" % params, body, headers)
        response = conn.getresponse()
        data = response.read()

        # 'data' contains the JSON data. The following formats the JSON data for display.
        parsed = json.loads(data)
        print ("Response:", index)
        #print (json.dumps(parsed, sort_keys=True, indent=2))

        df['ImageText'][index] = parsed 
        df['ContainsText'][index] = str(parsed['orientation'] != 'NotDetected')
        
    except Exception as e:
        
        
        print("Sleeping for 60 seconds")
        print("Index Number",index)
        time.sleep(61)          
        
        # Execute the REST API call and get the response.
        conn = httplib.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
        conn.request("POST", "/vision/v1.0/ocr?%s" % params, body, headers)
        response = conn.getresponse()
        data = response.read()

        # 'data' contains the JSON data. The following formats the JSON data for display.
        parsed = json.loads(data)
        print ("Response:", index)
        #print (json.dumps(parsed, sort_keys=True, indent=2))

        df['ImageText'][index] = parsed 
        df['ContainsText'][index] = str(parsed['orientation'] != 'NotDetected')
        
conn.close()
# Out:
# {'url':'https://i.ytimg.com/vi/AUzyaHo0QQc/default.jpg'}
# ('Response:', 0)
# {'url':'https://i.ytimg.com/vi/1Zgtdb7jp60/default.jpg'}
# C:\Users\kevjy\Anaconda\lib\site-packages\ipykernel_launcher.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\kevjy\Anaconda\lib\site-packages\ipykernel_launcher.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ('Response:', 1)
# {'url':'https://i.ytimg.com/vi/1Sfii7rnkJQ/default.jpg'}
# ('Response:', 2)
# {'url':'https://i.ytimg.com/vi/UUwSKJjx9Go/default.jpg'}
# ('Response:', 3)
# {'url':'https://i.ytimg.com/vi/Yl3NGvna2KA/default.jpg'}
# ('Response:', 4)
# {'url':'https://i.ytimg.com/vi/EBVTMSKY-Cw/default.jpg'}
# ('Response:', 5)
# {'url':'https://i.ytimg.com/vi/y04s-zEl5GM/default.jpg'}
# ('Response:', 6)
# {'url':'https://i.ytimg.com/vi/Ff84gG3bgVI/default.jpg'}
# ('Response:', 7)
# {'url':'https://i.ytimg.com/vi/jLS7S-nRS70/default.jpg'}
# ('Response:', 8)
# {'url':'https://i.ytimg.com/vi/yOgRXblTEjI/default.jpg'}
# ('Response:', 9)
# {'url':'https://i.ytimg.com/vi/WI-2scOeXU0/default.jpg'}
# ('Response:', 10)
# {'url':'https://i.ytimg.com/vi/QdmYTYAqHG4/default.jpg'}
# ('Response:', 11)
# {'url':'https://i.ytimg.com/vi/QyKYEKrYraI/default.jpg'}
# ('Response:', 12)
# {'url':'https://i.ytimg.com/vi/VnNH6OMqT9E/default.jpg'}
# ('Response:', 13)
# {'url':'https://i.ytimg.com/vi/U_I9LcWNrBg/default.jpg'}
# ('Response:', 14)
# {'url':'https://i.ytimg.com/vi/isb4txkVPrk/default.jpg'}
# ('Response:', 15)
# {'url':'https://i.ytimg.com/vi/yAFTAcNP1VA/default.jpg'}
# ('Response:', 16)
# {'url':'https://i.ytimg.com/vi/v8eQxP7lszM/default.jpg'}
# ('Response:', 17)
# {'url':'https://i.ytimg.com/vi/o-IVVhPrZ0A/default.jpg'}
# ('Response:', 18)
# {'url':'https://i.ytimg.com/vi/VWZSkDJP0-I/default.jpg'}
# ('Response:', 19)
# {'url':'https://i.ytimg.com/vi/nJCCW1ZH4QI/default.jpg'}
# ('Response:', 20)
# Sleeping for 60 seconds
# ('Index Number', 20)
# ('Response:', 20)
# {'url':'https://i.ytimg.com/vi/GEzgVs1YG-s/default.jpg'}
# C:\Users\kevjy\Anaconda\lib\site-packages\ipykernel_launcher.py:72: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\kevjy\Anaconda\lib\site-packages\ipykernel_launcher.py:73: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ('Response:', 21)
# {'url':'https://i.ytimg.com/vi/FnYYqmoRI9k/default.jpg'}
# ('Response:', 22)
# {'url':'https://i.ytimg.com/vi/6ZXv4V_JR8g/default.jpg'}
# ('Response:', 23)
# {'url':'https://i.ytimg.com/vi/i0RCIjZ7nHo/default.jpg'}
# ('Response:', 24)
# {'url':'https://i.ytimg.com/vi/i_DCpA-0haE/default.jpg'}
# ('Response:', 25)
# {'url':'https://i.ytimg.com/vi/73isTrLxrX4/default.jpg'}
# ('Response:', 26)
# {'url':'https://i.ytimg.com/vi/WNvxFjzSs58/default.jpg'}
# ('Response:', 27)
# {'url':'https://i.ytimg.com/vi/L4S7sYup_Rw/default.jpg'}
# ('Response:', 28)
# {'url':'https://i.ytimg.com/vi/ctfe4HwAb48/default.jpg'}
# ('Response:', 29)
# {'url':'https://i.ytimg.com/vi/b2wy7po5weA/default.jpg'}
# ('Response:', 30)
# {'url':'https://i.ytimg.com/vi/ThnZ0n-7x4E/default.jpg'}
# ('Response:', 31)
# {'url':'https://i.ytimg.com/vi/aX-YuvQkSRE/default.jpg'}
# ('Response:', 32)
# {'url':'https://i.ytimg.com/vi/BmraSo9GZEc/default.jpg'}
# ('Response:', 33)
# {'url':'https://i.ytimg.com/vi/EquFzTGMUgY/default.jpg'}
# ('Response:', 34)
# {'url':'https://i.ytimg.com/vi/4DvE0X-OOSs/default.jpg'}
# ('Response:', 35)
# {'url':'https://i.ytimg.com/vi/nVmtWsMelKQ/default.jpg'}
# ('Response:', 36)
# {'url':'https://i.ytimg.com/vi/gPPR0cd24cU/default.jpg'}
# ('Response:', 37)
# {'url':'https://i.ytimg.com/vi/XPiRjyR74Y8/default.jpg'}
# ('Response:', 38)
# {'url':'https://i.ytimg.com/vi/UYJMinNrB7E/default.jpg'}
# ('Response:', 39)
# {'url':'https://i.ytimg.com/vi/4rjXTEjrcr8/default.jpg'}
# ('Response:', 40)
# Sleeping for 60 seconds
# ('Index Number', 40)
# ('Response:', 40)
# {'url':'https://i.ytimg.com/vi/r9-uVemP5aU/default.jpg'}
# ('Response:', 41)
# {'url':'https://i.ytimg.com/vi/54krdTEyziQ/default.jpg'}
# ('Response:', 42)
# {'url':'https://i.ytimg.com/vi/A1wgc1CbA1I/default.jpg'}
# ('Response:', 43)
# {'url':'https://i.ytimg.com/vi/3yOi__pTTmw/default.jpg'}
# ('Response:', 44)
# {'url':'https://i.ytimg.com/vi/XywyHfqszcE/default.jpg'}
# ('Response:', 45)
# {'url':'https://i.ytimg.com/vi/QwGdELeJ610/default.jpg'}
# ('Response:', 46)
# {'url':'https://i.ytimg.com/vi/P41ER1Wmkj0/default.jpg'}
# ('Response:', 47)
# {'url':'https://i.ytimg.com/vi/J0FZvaUg_l8/default.jpg'}
# ('Response:', 48)
# {'url':'https://i.ytimg.com/vi/EWs0yOcnnww/default.jpg'}
# ('Response:', 49)
# {'url':'https://i.ytimg.com/vi/T3mTPq5fFNw/default.jpg'}
# ('Response:', 50)
# {'url':'https://i.ytimg.com/vi/7f-wV5s3r_Q/default.jpg'}
# ('Response:', 51)
# {'url':'https://i.ytimg.com/vi/245CE6RIDj4/default.jpg'}
# ('Response:', 52)
# {'url':'https://i.ytimg.com/vi/5l5ihWGtLUQ/default.jpg'}
# ('Response:', 53)
# {'url':'https://i.ytimg.com/vi/Y3DzOoQJuEA/default.jpg'}
# ('Response:', 54)
# {'url':'https://i.ytimg.com/vi/rzWQKAB3fYk/default.jpg'}
# ('Response:', 55)
# {'url':'https://i.ytimg.com/vi/_SQl5rnJZ9s/default.jpg'}
# ('Response:', 56)
# {'url':'https://i.ytimg.com/vi/1VDYD_ERmCU/default.jpg'}
# ('Response:', 57)
# {'url':'https://i.ytimg.com/vi/EdOj4j0vhos/default.jpg'}
# ('Response:', 58)
# {'url':'https://i.ytimg.com/vi/Ww14MvFQD4U/default.jpg'}
# ('Response:', 59)
# {'url':'https://i.ytimg.com/vi/TQFEeTlj8fg/default.jpg'}
# ('Response:', 60)
# Sleeping for 60 seconds
# ('Index Number', 60)
# ('Response:', 60)
# {'url':'https://i.ytimg.com/vi/ZJMIMgWBKLI/default.jpg'}
# ('Response:', 61)
# {'url':'https://i.ytimg.com/vi/QOh33sNOw3k/default.jpg'}
# ('Response:', 62)
# {'url':'https://i.ytimg.com/vi/1vcBQNqfxe8/default.jpg'}
# ('Response:', 63)
# {'url':'https://i.ytimg.com/vi/rzYG2b7wc5U/default.jpg'}
# ('Response:', 64)
# {'url':'https://i.ytimg.com/vi/AIZDTGqBa-0/default.jpg'}
# ('Response:', 65)
# {'url':'https://i.ytimg.com/vi/IDecoDlrdqY/default.jpg'}
# ('Response:', 66)
# {'url':'https://i.ytimg.com/vi/CS0Q0keZOH8/default.jpg'}
# ('Response:', 67)
# {'url':'https://i.ytimg.com/vi/9FwIDwBDcnA/default.jpg'}
# ('Response:', 68)
# {'url':'https://i.ytimg.com/vi/JBHzXF-mVjY/default.jpg'}
# ('Response:', 69)
# {'url':'https://i.ytimg.com/vi/3HeQwKnVm_E/default.jpg'}
# ('Response:', 70)
# {'url':'https://i.ytimg.com/vi/EMNIoKcg48s/default.jpg'}
# ('Response:', 71)
# {'url':'https://i.ytimg.com/vi/qZ6NX4yQLCo/default.jpg'}
# ('Response:', 72)
# {'url':'https://i.ytimg.com/vi/NwRLol7Jxq8/default.jpg'}
# ('Response:', 73)
# {'url':'https://i.ytimg.com/vi/VKDTB1F-jRw/default.jpg'}
# ('Response:', 74)
# {'url':'https://i.ytimg.com/vi/XN9tlgb4Sls/default.jpg'}
# ('Response:', 75)
# {'url':'https://i.ytimg.com/vi/FLszsAvvg7c/default.jpg'}
# ('Response:', 76)
# {'url':'https://i.ytimg.com/vi/9Rhn6e0LSjo/default.jpg'}
# ('Response:', 77)
# {'url':'https://i.ytimg.com/vi/3BoZkxpz60g/default.jpg'}
# ('Response:', 78)
# {'url':'https://i.ytimg.com/vi/k7tDnnlGQEI/default.jpg'}
# ('Response:', 79)
# {'url':'https://i.ytimg.com/vi/r2j3Rm0S2WA/default.jpg'}
# ('Response:', 80)
# Sleeping for 60 seconds
# ('Index Number', 80)
# ('Response:', 80)
# {'url':'https://i.ytimg.com/vi/-o6fZNSblkw/default.jpg'}
# ('Response:', 81)
# {'url':'https://i.ytimg.com/vi/YDBJeUq89L4/default.jpg'}
# ('Response:', 82)
# {'url':'https://i.ytimg.com/vi/EdNkJ9e5254/default.jpg'}
# ('Response:', 83)
# {'url':'https://i.ytimg.com/vi/R_dW1Qf-Ggw/default.jpg'}
# ('Response:', 84)
# {'url':'https://i.ytimg.com/vi/SW_C1A-rejs/default.jpg'}
# ('Response:', 85)
# {'url':'https://i.ytimg.com/vi/6WAbm6aZweg/default.jpg'}
# ('Response:', 86)
# {'url':'https://i.ytimg.com/vi/dK67nr6DEsc/default.jpg'}
# ('Response:', 87)
# {'url':'https://i.ytimg.com/vi/q7i2EsD3ZuA/default.jpg'}
# ('Response:', 88)
# {'url':'https://i.ytimg.com/vi/gkYz3NlQA7w/default.jpg'}
# ('Response:', 89)
# {'url':'https://i.ytimg.com/vi/C2uJ-tWSZew/default.jpg'}
# ('Response:', 90)
# {'url':'https://i.ytimg.com/vi/4J-rrJo5SQ0/default.jpg'}
# ('Response:', 91)
# {'url':'https://i.ytimg.com/vi/Z92ofAkVuQo/default.jpg'}
# ('Response:', 92)
# {'url':'https://i.ytimg.com/vi/W0pXq2bXm9c/default.jpg'}
# ('Response:', 93)
# {'url':'https://i.ytimg.com/vi/JKt9C47UfEA/default.jpg'}
# ('Response:', 94)
# {'url':'https://i.ytimg.com/vi/V1muRbBIYnI/default.jpg'}
# ('Response:', 95)
# {'url':'https://i.ytimg.com/vi/tSThE5jg0u0/default.jpg'}
# ('Response:', 96)
# {'url':'https://i.ytimg.com/vi/LSPtj1drMa0/default.jpg'}
# ('Response:', 97)
# {'url':'https://i.ytimg.com/vi/CDPLsiN5huk/default.jpg'}
# ('Response:', 98)
# {'url':'https://i.ytimg.com/vi/VQnquhvkxFc/default.jpg'}
# ('Response:', 99)
# {'url':'https://i.ytimg.com/vi/THDLm-2QA1I/default.jpg'}
# ('Response:', 100)
# Sleeping for 60 seconds
# ('Index Number', 100)
# ('Response:', 100)
# {'url':'https://i.ytimg.com/vi/WWpgA9aDb1U/default.jpg'}
# ('Response:', 101)
# {'url':'https://i.ytimg.com/vi/gGKTsp6U2z4/default.jpg'}
# ('Response:', 102)
# {'url':'https://i.ytimg.com/vi/0Gn3hLE28bw/default.jpg'}
# ('Response:', 103)
# {'url':'https://i.ytimg.com/vi/JKYnXh9je7E/default.jpg'}
# ('Response:', 104)
# {'url':'https://i.ytimg.com/vi/t9w9gQmnuhg/default.jpg'}
# ('Response:', 105)
# {'url':'https://i.ytimg.com/vi/r7n-jEMsljA/default.jpg'}
# ('Response:', 106)
# {'url':'https://i.ytimg.com/vi/8Dz39zCtMDs/default.jpg'}
# ('Response:', 107)
# {'url':'https://i.ytimg.com/vi/ABbUH9SUYe8/default.jpg'}
# ('Response:', 108)
# {'url':'https://i.ytimg.com/vi/0_RNf3_fS9Q/default.jpg'}
# ('Response:', 109)
# {'url':'https://i.ytimg.com/vi/pWw-yE5X-kE/default.jpg'}
# ('Response:', 110)
# {'url':'https://i.ytimg.com/vi/-5E7mKtAQ9A/default.jpg'}
# ('Response:', 111)
# {'url':'https://i.ytimg.com/vi/tl_Hp1Wf52k/default.jpg'}
# ('Response:', 112)
# {'url':'https://i.ytimg.com/vi/6_x9qA4DPj8/default.jpg'}
# ('Response:', 113)
# {'url':'https://i.ytimg.com/vi/2oxruLoiGhI/default.jpg'}
# ('Response:', 114)
# {'url':'https://i.ytimg.com/vi/00TVwlY4i6Y/default.jpg'}
# ('Response:', 115)
# {'url':'https://i.ytimg.com/vi/Q_o0X1x7cws/default.jpg'}
# ('Response:', 116)
# {'url':'https://i.ytimg.com/vi/6jvNeHoJA8A/default.jpg'}
# ('Response:', 117)
# {'url':'https://i.ytimg.com/vi/4Ig-lQqNrYI/default.jpg'}
# ('Response:', 118)
# {'url':'https://i.ytimg.com/vi/ICcYm49SsMk/default.jpg'}
# ('Response:', 119)
# {'url':'https://i.ytimg.com/vi/gPI-E2lvJxE/default.jpg'}
# ('Response:', 120)
# Sleeping for 60 seconds
# ('Index Number', 120)
# ('Response:', 120)
# {'url':'https://i.ytimg.com/vi/HL9v6ZEHGL4/default.jpg'}
# ('Response:', 121)
# {'url':'https://i.ytimg.com/vi/GvW_D4dqj9Q/default.jpg'}
# ('Response:', 122)
# {'url':'https://i.ytimg.com/vi/TG_OxbwpdBo/default.jpg'}
# ('Response:', 123)
# {'url':'https://i.ytimg.com/vi/80IvTN0CRoU/default.jpg'}
# ('Response:', 124)
# {'url':'https://i.ytimg.com/vi/eCl_toGA8zQ/default.jpg'}
# ('Response:', 125)
# {'url':'https://i.ytimg.com/vi/OXu6JIlhkAY/default.jpg'}
# ('Response:', 126)
# {'url':'https://i.ytimg.com/vi/XWO7hxF9neQ/default.jpg'}
# ('Response:', 127)
# {'url':'https://i.ytimg.com/vi/Wdp_dsbgwrM/default.jpg'}
# ('Response:', 128)
# {'url':'https://i.ytimg.com/vi/OSckGzMkuB4/default.jpg'}
# ('Response:', 129)
# {'url':'https://i.ytimg.com/vi/sVylMFWSIYw/default.jpg'}
# ('Response:', 130)
# {'url':'https://i.ytimg.com/vi/4vcB2kJazaA/default.jpg'}
# ('Response:', 131)
# {'url':'https://i.ytimg.com/vi/RjKkuSvFuOk/default.jpg'}
# ('Response:', 132)
# {'url':'https://i.ytimg.com/vi/PYJgukiEXyQ/default.jpg'}
# ('Response:', 133)
# {'url':'https://i.ytimg.com/vi/jF5z4j3MtDk/default.jpg'}
# ('Response:', 134)
# {'url':'https://i.ytimg.com/vi/w9mr3DPM7xU/default.jpg'}
# ('Response:', 135)
# {'url':'https://i.ytimg.com/vi/J9nGjRZBqTo/default.jpg'}
# ('Response:', 136)
# {'url':'https://i.ytimg.com/vi/1mKR5Cmr3pE/default.jpg'}
# ('Response:', 137)
# {'url':'https://i.ytimg.com/vi/y7RlGss3Ars/default.jpg'}
# ('Response:', 138)
# {'url':'https://i.ytimg.com/vi/TezSv6woBVU/default.jpg'}
# ('Response:', 139)
# {'url':'https://i.ytimg.com/vi/5LjAnUjqG5M/default.jpg'}
# ('Response:', 140)
# Sleeping for 60 seconds
# ('Index Number', 140)
# ('Response:', 140)
# {'url':'https://i.ytimg.com/vi/zmXLqmqBzeU/default.jpg'}
# ('Response:', 141)
# {'url':'https://i.ytimg.com/vi/QWWsTW3wVeQ/default.jpg'}
# ('Response:', 142)
# {'url':'https://i.ytimg.com/vi/l_e9T1TAszI/default.jpg'}
# ('Response:', 143)
# {'url':'https://i.ytimg.com/vi/HZfrrA7qKPI/default.jpg'}
# ('Response:', 144)
# {'url':'https://i.ytimg.com/vi/IkxhO-uoEHk/default.jpg'}
# ('Response:', 145)
# {'url':'https://i.ytimg.com/vi/C8EVUZf2y0Y/default.jpg'}
# ('Response:', 146)
# {'url':'https://i.ytimg.com/vi/WuQSnEClkGo/default.jpg'}
# ('Response:', 147)
# {'url':'https://i.ytimg.com/vi/qCyhYkljIMw/default.jpg'}
# ('Response:', 148)
# {'url':'https://i.ytimg.com/vi/1O6hLDdE7uM/default.jpg'}
# ('Response:', 149)
# {'url':'https://i.ytimg.com/vi/jxEMEyu5KBk/default.jpg'}
# ('Response:', 150)
# {'url':'https://i.ytimg.com/vi/nL7TB5NDu6M/default.jpg'}
# ('Response:', 151)
# {'url':'https://i.ytimg.com/vi/ZA3_Np0DY_M/default.jpg'}
# ('Response:', 152)
# {'url':'https://i.ytimg.com/vi/Wd7SGqKOp1U/default.jpg'}
# ('Response:', 153)
# {'url':'https://i.ytimg.com/vi/shk3XbDgpHg/default.jpg'}
# ('Response:', 154)
# {'url':'https://i.ytimg.com/vi/ynhlZ9AmxG8/default.jpg'}
# ('Response:', 155)
# {'url':'https://i.ytimg.com/vi/UZWVQ1rtsyQ/default.jpg'}
# ('Response:', 156)
# {'url':'https://i.ytimg.com/vi/ZdU2D56zkvQ/default.jpg'}
# ('Response:', 157)
# {'url':'https://i.ytimg.com/vi/AEfbhgqRX-8/default.jpg'}
# ('Response:', 158)
# {'url':'https://i.ytimg.com/vi/2ePNzQ6RY54/default.jpg'}
# ('Response:', 159)
# {'url':'https://i.ytimg.com/vi/jcAJOwZ4vc8/default.jpg'}
# ('Response:', 160)
# Sleeping for 60 seconds
# ('Index Number', 160)
# ('Response:', 160)
# {'url':'https://i.ytimg.com/vi/vPKcShZzuPo/default.jpg'}
# ('Response:', 161)
# {'url':'https://i.ytimg.com/vi/6UDwvOVthzA/default.jpg'}
# ('Response:', 162)
# {'url':'https://i.ytimg.com/vi/VUiFlZ2FsKA/default.jpg'}
# ('Response:', 163)
# {'url':'https://i.ytimg.com/vi/wkRkzVEnuMY/default.jpg'}
# ('Response:', 164)
# {'url':'https://i.ytimg.com/vi/F-msmPPaBdM/default.jpg'}
# ('Response:', 165)
# {'url':'https://i.ytimg.com/vi/r_tBJciL6QE/default.jpg'}
# ('Response:', 166)
# {'url':'https://i.ytimg.com/vi/6n4h0BXrrFU/default.jpg'}
# ('Response:', 167)
# {'url':'https://i.ytimg.com/vi/IqYhU3LWATU/default.jpg'}
# ('Response:', 168)
# {'url':'https://i.ytimg.com/vi/pZKO8KhtyCQ/default.jpg'}
# ('Response:', 169)
# {'url':'https://i.ytimg.com/vi/CjiP-rxVpcM/default.jpg'}
# ('Response:', 170)
# {'url':'https://i.ytimg.com/vi/Ydk8JZo_g6I/default.jpg'}
# ('Response:', 171)
# {'url':'https://i.ytimg.com/vi/FMq8Stkircc/default.jpg'}
# ('Response:', 172)
# {'url':'https://i.ytimg.com/vi/XIhL6DEo1LQ/default.jpg'}
# ('Response:', 173)
# {'url':'https://i.ytimg.com/vi/MG3MQfIBEO8/default.jpg'}
# ('Response:', 174)
# {'url':'https://i.ytimg.com/vi/JK7v4e1yZSw/default.jpg'}
# ('Response:', 175)
# {'url':'https://i.ytimg.com/vi/0pnpdS-8NaY/default.jpg'}
# ('Response:', 176)
# {'url':'https://i.ytimg.com/vi/EUzaw5_O9vY/default.jpg'}
# ('Response:', 177)
# {'url':'https://i.ytimg.com/vi/kSutLO2oa7I/default.jpg'}
# ('Response:', 178)
# {'url':'https://i.ytimg.com/vi/QnPqzf_K22s/default.jpg'}
# ('Response:', 179)
# {'url':'https://i.ytimg.com/vi/W_Gfi5lRhNQ/default.jpg'}
# ('Response:', 180)
# Sleeping for 60 seconds
# ('Index Number', 180)
# ('Response:', 180)
# {'url':'https://i.ytimg.com/vi/M1iXSymLsIA/default.jpg'}
# ('Response:', 181)
# {'url':'https://i.ytimg.com/vi/BIoRhLrmxM8/default.jpg'}
# ('Response:', 182)
# {'url':'https://i.ytimg.com/vi/5yn9QBTppgo/default.jpg'}
# ('Response:', 183)
# {'url':'https://i.ytimg.com/vi/NP1wrsC0raI/default.jpg'}
# ('Response:', 184)
# {'url':'https://i.ytimg.com/vi/VfNNEkofRFk/default.jpg'}
# ('Response:', 185)
# {'url':'https://i.ytimg.com/vi/WIKrcoO86h4/default.jpg'}
# ('Response:', 186)
# {'url':'https://i.ytimg.com/vi/7UXb8JXNq9E/default.jpg'}
# ('Response:', 187)
# {'url':'https://i.ytimg.com/vi/eCwcKEUcqcU/default.jpg'}
# ('Response:', 188)
# {'url':'https://i.ytimg.com/vi/1f-fMN2v8Uk/default.jpg'}
# ('Response:', 189)
# {'url':'https://i.ytimg.com/vi/DAx5Tcq5Qrk/default.jpg'}
# ('Response:', 190)
# {'url':'https://i.ytimg.com/vi/4_nOqg5eM-A/default.jpg'}
# ('Response:', 191)
# {'url':'https://i.ytimg.com/vi/Z6uiYbyr6ek/default.jpg'}
# ('Response:', 192)
# {'url':'https://i.ytimg.com/vi/HRY6dIBRUu8/default.jpg'}
# ('Response:', 193)
# {'url':'https://i.ytimg.com/vi/7TIaSnN0Gdc/default.jpg'}
# ('Response:', 194)
# {'url':'https://i.ytimg.com/vi/ZJ_Il0tPt8c/default.jpg'}
# ('Response:', 195)
# {'url':'https://i.ytimg.com/vi/45I-cZtsgno/default.jpg'}
# ('Response:', 196)
# {'url':'https://i.ytimg.com/vi/IWxerVP5eps/default.jpg'}
# ('Response:', 197)
# {'url':'https://i.ytimg.com/vi/VOIRYCivodQ/default.jpg'}
# ('Response:', 198)
# {'url':'https://i.ytimg.com/vi/GZbpUB5DoaY/default.jpg'}
# ('Response:', 199)
# {'url':'https://i.ytimg.com/vi/yBJVL-uPAXU/default.jpg'}
# ('Response:', 200)
# Sleeping for 60 seconds
# ('Index Number', 200)
# ('Response:', 200)
# {'url':'https://i.ytimg.com/vi/hMtcAQKDieE/default.jpg'}
# ('Response:', 201)
# {'url':'https://i.ytimg.com/vi/T2-Rblkf79o/default.jpg'}
# ('Response:', 202)
# {'url':'https://i.ytimg.com/vi/xJPqWqTciQA/default.jpg'}
# ('Response:', 203)
# {'url':'https://i.ytimg.com/vi/b3SJIw1PraI/default.jpg'}
# ('Response:', 204)
# {'url':'https://i.ytimg.com/vi/BYuCigL0NBY/default.jpg'}
# ('Response:', 205)
# {'url':'https://i.ytimg.com/vi/77CHby-kK7I/default.jpg'}
# ('Response:', 206)
# {'url':'https://i.ytimg.com/vi/gWvt40JHwJs/default.jpg'}
# ('Response:', 207)
# {'url':'https://i.ytimg.com/vi/9AOjYKtI0BA/default.jpg'}
# ('Response:', 208)
# {'url':'https://i.ytimg.com/vi/AsFN1dG2jO0/default.jpg'}
# ('Response:', 209)
# {'url':'https://i.ytimg.com/vi/O4MQowx8h3A/default.jpg'}
# ('Response:', 210)
# {'url':'https://i.ytimg.com/vi/6LDlLT6J2g8/default.jpg'}
# ('Response:', 211)
# {'url':'https://i.ytimg.com/vi/aRVg-qjsgMU/default.jpg'}
# ('Response:', 212)
# {'url':'https://i.ytimg.com/vi/O_2XG7qpsHs/default.jpg'}
# ('Response:', 213)
# {'url':'https://i.ytimg.com/vi/Hkjsd8VmCZ8/default.jpg'}
# ('Response:', 214)
# {'url':'https://i.ytimg.com/vi/CmIwyWrcXRE/default.jpg'}
# ('Response:', 215)
# {'url':'https://i.ytimg.com/vi/ctP3n60e36o/default.jpg'}
# ('Response:', 216)
# {'url':'https://i.ytimg.com/vi/8kUlTKXknRo/default.jpg'}
# ('Response:', 217)
# {'url':'https://i.ytimg.com/vi/DV9cUGQN1rQ/default.jpg'}
# ('Response:', 218)
# {'url':'https://i.ytimg.com/vi/jcFHZ_7lf-E/default.jpg'}
# ('Response:', 219)
# {'url':'https://i.ytimg.com/vi/dugVes7U1ow/default.jpg'}
# ('Response:', 220)
# Sleeping for 60 seconds
# ('Index Number', 220)
# ('Response:', 220)
# {'url':'https://i.ytimg.com/vi/ZGSqwOU0feg/default.jpg'}
# ('Response:', 221)
# {'url':'https://i.ytimg.com/vi/Aik09ivBzws/default.jpg'}
# ('Response:', 222)
# {'url':'https://i.ytimg.com/vi/V7ZubJ5hJpU/default.jpg'}
# ('Response:', 223)
# {'url':'https://i.ytimg.com/vi/_I5ROV4yb6I/default.jpg'}
# ('Response:', 224)
# {'url':'https://i.ytimg.com/vi/Q_b96EtwUbY/default.jpg'}
# ('Response:', 225)
# {'url':'https://i.ytimg.com/vi/CVTkbggmxR0/default.jpg'}
# ('Response:', 226)
# {'url':'https://i.ytimg.com/vi/PJ0E5UT04Rw/default.jpg'}
# ('Response:', 227)
# {'url':'https://i.ytimg.com/vi/7oKWugCTFMY/default.jpg'}
# ('Response:', 228)
# {'url':'https://i.ytimg.com/vi/N7tMleuqE1k/default.jpg'}
# ('Response:', 229)
# {'url':'https://i.ytimg.com/vi/9vaoR2Rn_Vs/default.jpg'}
# ('Response:', 230)
# {'url':'https://i.ytimg.com/vi/OOGJ1CWU8qQ/default.jpg'}
# ('Response:', 231)
# {'url':'https://i.ytimg.com/vi/-4ohaaxds2M/default.jpg'}
# ('Response:', 232)
# {'url':'https://i.ytimg.com/vi/H-WRUhJBUao/default.jpg'}
# ('Response:', 233)
# {'url':'https://i.ytimg.com/vi/R5iLUJm2l3k/default.jpg'}
# ('Response:', 234)
# {'url':'https://i.ytimg.com/vi/WKEFIiDGM7o/default.jpg'}
# ('Response:', 235)
# {'url':'https://i.ytimg.com/vi/1obYWF6jSoc/default.jpg'}
# ('Response:', 236)
# {'url':'https://i.ytimg.com/vi/dK_xKvsVI0E/default.jpg'}
# ('Response:', 237)
# {'url':'https://i.ytimg.com/vi/gmxSxwjAWVE/default.jpg'}
# ('Response:', 238)
# {'url':'https://i.ytimg.com/vi/WVtZhSOGshc/default.jpg'}
# ('Response:', 239)
# {'url':'https://i.ytimg.com/vi/y-6vq0hDFbc/default.jpg'}
# ('Response:', 240)
# Sleeping for 60 seconds
# ('Index Number', 240)
# ('Response:', 240)
# {'url':'https://i.ytimg.com/vi/0fVWo5ruXUc/default.jpg'}
# ('Response:', 241)
# {'url':'https://i.ytimg.com/vi/W0wNSoJ3S3s/default.jpg'}
# ('Response:', 242)
# {'url':'https://i.ytimg.com/vi/BedjYsV83-k/default.jpg'}
# ('Response:', 243)
# {'url':'https://i.ytimg.com/vi/XdO9dvahSJ8/default.jpg'}
# ('Response:', 244)
# {'url':'https://i.ytimg.com/vi/RCjy78rSxvY/default.jpg'}
# ('Response:', 245)
# {'url':'https://i.ytimg.com/vi/-tG1ucfInMM/default.jpg'}
# ('Response:', 246)
# {'url':'https://i.ytimg.com/vi/mWudi3gOBqM/default.jpg'}
# ('Response:', 247)
# {'url':'https://i.ytimg.com/vi/QLteROnAnpA/default.jpg'}
# ('Response:', 248)
# {'url':'https://i.ytimg.com/vi/ALzFr2GT-Is/default.jpg'}
# ('Response:', 249)
# {'url':'https://i.ytimg.com/vi/CnNoeuRVpIo/default.jpg'}
# ('Response:', 250)
# {'url':'https://i.ytimg.com/vi/MCAoj3H9qz4/default.jpg'}
# ('Response:', 251)
# {'url':'https://i.ytimg.com/vi/6Qjo7izSMa4/default.jpg'}
# ('Response:', 252)
# {'url':'https://i.ytimg.com/vi/C7vVhfnEWas/default.jpg'}
# ('Response:', 253)
# {'url':'https://i.ytimg.com/vi/C3a6NVsE6Pk/default.jpg'}
# ('Response:', 254)
# {'url':'https://i.ytimg.com/vi/OpvTpc_nauI/default.jpg'}
# ('Response:', 255)
# {'url':'https://i.ytimg.com/vi/NHoum2caBoM/default.jpg'}
# ('Response:', 256)
# {'url':'https://i.ytimg.com/vi/xUJLJbivMvY/default.jpg'}
# ('Response:', 257)
# {'url':'https://i.ytimg.com/vi/vO1JCV3-5VY/default.jpg'}
# ('Response:', 258)
# {'url':'https://i.ytimg.com/vi/z0q-b6g-Vwc/default.jpg'}
# ('Response:', 259)
# {'url':'https://i.ytimg.com/vi/T6D483GYqAk/default.jpg'}
# ('Response:', 260)
# Sleeping for 60 seconds
# ('Index Number', 260)
# ('Response:', 260)
# {'url':'https://i.ytimg.com/vi/NinnkhFT3R4/default.jpg'}
# ('Response:', 261)
# {'url':'https://i.ytimg.com/vi/FiQDNhsVyzw/default.jpg'}
# ('Response:', 262)
# {'url':'https://i.ytimg.com/vi/I_MCHhWz_w0/default.jpg'}
# ('Response:', 263)
# {'url':'https://i.ytimg.com/vi/jbIPJSxMgps/default.jpg'}
# ('Response:', 264)
# {'url':'https://i.ytimg.com/vi/HMQsFZFSbLs/default.jpg'}
# ('Response:', 265)
# {'url':'https://i.ytimg.com/vi/Eg-yY3J5fV0/default.jpg'}
# ('Response:', 266)
# {'url':'https://i.ytimg.com/vi/yJTPR5RIfGw/default.jpg'}
# ('Response:', 267)
# {'url':'https://i.ytimg.com/vi/9iuuwdy24is/default.jpg'}
# ('Response:', 268)
# {'url':'https://i.ytimg.com/vi/W1SD96lrudY/default.jpg'}
# ('Response:', 269)
# {'url':'https://i.ytimg.com/vi/WNEYaWgO22g/default.jpg'}
# ('Response:', 270)
# {'url':'https://i.ytimg.com/vi/sDGZON-08D8/default.jpg'}
# ('Response:', 271)
# {'url':'https://i.ytimg.com/vi/-VqzSpq45CE/default.jpg'}
# ('Response:', 272)
# {'url':'https://i.ytimg.com/vi/8xrSfuUhhqs/default.jpg'}
# ('Response:', 273)
# {'url':'https://i.ytimg.com/vi/262KvHrfJ4I/default.jpg'}
# ('Response:', 274)
# {'url':'https://i.ytimg.com/vi/HRG9aIT8AUQ/default.jpg'}
# ('Response:', 275)
# {'url':'https://i.ytimg.com/vi/t4DlbzKziJM/default.jpg'}
# ('Response:', 276)
# {'url':'https://i.ytimg.com/vi/-1l-a_ZAhlU/default.jpg'}
# ('Response:', 277)
# {'url':'https://i.ytimg.com/vi/yHNAeow4UV0/default.jpg'}
# ('Response:', 278)
# {'url':'https://i.ytimg.com/vi/3e0VHSkz5gM/default.jpg'}
# ('Response:', 279)
# {'url':'https://i.ytimg.com/vi/6Z-14-btYUo/default.jpg'}
# ('Response:', 280)
# Sleeping for 60 seconds
# ('Index Number', 280)
# ('Response:', 280)
# {'url':'https://i.ytimg.com/vi/GBb0rVZLAws/default.jpg'}
# ('Response:', 281)
# {'url':'https://i.ytimg.com/vi/N7t7FtqBR6U/default.jpg'}
# ('Response:', 282)
# {'url':'https://i.ytimg.com/vi/S7AH-xetUjw/default.jpg'}
# ('Response:', 283)
# {'url':'https://i.ytimg.com/vi/u1yuTprwWQE/default.jpg'}
# ('Response:', 284)
# {'url':'https://i.ytimg.com/vi/rBbKRopHqPA/default.jpg'}
# ('Response:', 285)
# {'url':'https://i.ytimg.com/vi/NAqCVe2mwzM/default.jpg'}
# ('Response:', 286)
# {'url':'https://i.ytimg.com/vi/B-t3bDOFAK8/default.jpg'}
# ('Response:', 287)
# {'url':'https://i.ytimg.com/vi/VdKOciw2Vec/default.jpg'}
# ('Response:', 288)
# {'url':'https://i.ytimg.com/vi/w3b2siAy5hs/default.jpg'}
# ('Response:', 289)
# {'url':'https://i.ytimg.com/vi/6u6YLTZOVqg/default.jpg'}
# ('Response:', 290)
# {'url':'https://i.ytimg.com/vi/fAQwN4t-2JI/default.jpg'}
# ('Response:', 291)
# {'url':'https://i.ytimg.com/vi/yLbKeAQK4GU/default.jpg'}
# ('Response:', 292)
# {'url':'https://i.ytimg.com/vi/3FQYQ8kEWE8/default.jpg'}
# ('Response:', 293)
# {'url':'https://i.ytimg.com/vi/Nfpyzz2om8E/default.jpg'}
# ('Response:', 294)
# {'url':'https://i.ytimg.com/vi/PXZTCrVZAhU/default.jpg'}
# ('Response:', 295)
# {'url':'https://i.ytimg.com/vi/VF-0KX8PF_o/default.jpg'}
# ('Response:', 296)
# {'url':'https://i.ytimg.com/vi/e1JbsA6GJU8/default.jpg'}
# ('Response:', 297)
# {'url':'https://i.ytimg.com/vi/BXY8jhivhH8/default.jpg'}
# ('Response:', 298)
# {'url':'https://i.ytimg.com/vi/TPPSKl4QN2g/default.jpg'}
# ('Response:', 299)
# {'url':'https://i.ytimg.com/vi/cbvarT0YoNw/default.jpg'}
# ('Response:', 300)
# Sleeping for 60 seconds
# ('Index Number', 300)
# ('Response:', 300)
# {'url':'https://i.ytimg.com/vi/w9Rp1C42uXk/default.jpg'}
# ('Response:', 301)
# {'url':'https://i.ytimg.com/vi/wTOUIf0K9SY/default.jpg'}
# ('Response:', 302)
# {'url':'https://i.ytimg.com/vi/moOY-kLFeBM/default.jpg'}
# ('Response:', 303)
# {'url':'https://i.ytimg.com/vi/b2a_TC3yyGQ/default.jpg'}
# ('Response:', 304)
# {'url':'https://i.ytimg.com/vi/BKgQ_z_iaV4/default.jpg'}
# ('Response:', 305)
# {'url':'https://i.ytimg.com/vi/JD2ILK--0Mc/default.jpg'}
# ('Response:', 306)
# {'url':'https://i.ytimg.com/vi/odEXYKifSpo/default.jpg'}
# ('Response:', 307)
# {'url':'https://i.ytimg.com/vi/5B7pzE-r9i8/default.jpg'}
# ('Response:', 308)
# {'url':'https://i.ytimg.com/vi/FFQOppbUBt8/default.jpg'}
# ('Response:', 309)
# {'url':'https://i.ytimg.com/vi/09hyB3MEj-Y/default.jpg'}
# ('Response:', 310)
# {'url':'https://i.ytimg.com/vi/GuVHzwxTqSo/default.jpg'}
# ('Response:', 311)
# {'url':'https://i.ytimg.com/vi/sawrBSMbmwg/default.jpg'}
# ('Response:', 312)
# {'url':'https://i.ytimg.com/vi/aNdZJXOuTIY/default.jpg'}
# ('Response:', 313)
# {'url':'https://i.ytimg.com/vi/2HQRJZ2q7PQ/default.jpg'}
# ('Response:', 314)
# {'url':'https://i.ytimg.com/vi/USJ-gurIdlM/default.jpg'}
# ('Response:', 315)
# {'url':'https://i.ytimg.com/vi/3DGwbomSLuw/default.jpg'}
# ('Response:', 316)
# {'url':'https://i.ytimg.com/vi/CDEhekunkj4/default.jpg'}
# ('Response:', 317)
# {'url':'https://i.ytimg.com/vi/3ZlPm4753Lg/default.jpg'}
# ('Response:', 318)
# {'url':'https://i.ytimg.com/vi/72rTpRmqEls/default.jpg'}
# ('Response:', 319)
# {'url':'https://i.ytimg.com/vi/oRNuvB8LZPo/default.jpg'}
# ('Response:', 320)
# Sleeping for 60 seconds
# ('Index Number', 320)
# ('Response:', 320)
# {'url':'https://i.ytimg.com/vi/YjO1CtidOqk/default.jpg'}
# ('Response:', 321)
# {'url':'https://i.ytimg.com/vi/2Ktxc82b0vc/default.jpg'}
# ('Response:', 322)
# {'url':'https://i.ytimg.com/vi/C-0Qe80fUaU/default.jpg'}
# ('Response:', 323)
# {'url':'https://i.ytimg.com/vi/HyUBBt5S_VU/default.jpg'}
# ('Response:', 324)
# {'url':'https://i.ytimg.com/vi/oLKOoO4Y8WY/default.jpg'}
# ('Response:', 325)
# {'url':'https://i.ytimg.com/vi/0BFPpBVTTP4/default.jpg'}
# ('Response:', 326)
# {'url':'https://i.ytimg.com/vi/0uj47CD72tA/default.jpg'}
# ('Response:', 327)
# {'url':'https://i.ytimg.com/vi/0LpOGIvd7KI/default.jpg'}
# ('Response:', 328)
# {'url':'https://i.ytimg.com/vi/UQCXLwoFlBA/default.jpg'}
# ('Response:', 329)
# {'url':'https://i.ytimg.com/vi/X_QyRRJOJf4/default.jpg'}
# ('Response:', 330)
# {'url':'https://i.ytimg.com/vi/TaZeuRBqZdg/default.jpg'}
# ('Response:', 331)
# {'url':'https://i.ytimg.com/vi/01jnD6OAqro/default.jpg'}
# ('Response:', 332)
# {'url':'https://i.ytimg.com/vi/MgpqmnfocJc/default.jpg'}
# ('Response:', 333)
# {'url':'https://i.ytimg.com/vi/aWFnF6MF2hQ/default.jpg'}
# ('Response:', 334)
# {'url':'https://i.ytimg.com/vi/Akp71PGEsoY/default.jpg'}
# ('Response:', 335)
# {'url':'https://i.ytimg.com/vi/UZrqofca8xw/default.jpg'}
# ('Response:', 336)
# {'url':'https://i.ytimg.com/vi/Im-j0T488P8/default.jpg'}
# ('Response:', 337)
# {'url':'https://i.ytimg.com/vi/xiDk6GqdrYU/default.jpg'}
# ('Response:', 338)
# {'url':'https://i.ytimg.com/vi/AI_o0yWC_ow/default.jpg'}
# ('Response:', 339)
# {'url':'https://i.ytimg.com/vi/6WJ0-6dRn_c/default.jpg'}
# ('Response:', 340)
# Sleeping for 60 seconds
# ('Index Number', 340)
# ('Response:', 340)
# {'url':'https://i.ytimg.com/vi/H3YpZ-Jez-0/default.jpg'}
# ('Response:', 341)
# {'url':'https://i.ytimg.com/vi/10n9GqT3itY/default.jpg'}
# ('Response:', 342)
# {'url':'https://i.ytimg.com/vi/0E7NvAl2BUg/default.jpg'}
# ('Response:', 343)
# {'url':'https://i.ytimg.com/vi/_ieSbXFh6d4/default.jpg'}
# ('Response:', 344)
# {'url':'https://i.ytimg.com/vi/tYMK7OwaCG8/default.jpg'}
# ('Response:', 345)
# {'url':'https://i.ytimg.com/vi/2S63wRnWxgE/default.jpg'}
# ('Response:', 346)
# {'url':'https://i.ytimg.com/vi/VBhJPhIgHF0/default.jpg'}
# ('Response:', 347)
# {'url':'https://i.ytimg.com/vi/L-nUDUv8xYU/default.jpg'}
# ('Response:', 348)
# {'url':'https://i.ytimg.com/vi/VWzRvpsk-ls/default.jpg'}
# ('Response:', 349)
# {'url':'https://i.ytimg.com/vi/4rGcdQcEwgU/default.jpg'}
# ('Response:', 350)
# {'url':'https://i.ytimg.com/vi/UQ9nJCKDYvc/default.jpg'}
# ('Response:', 351)
# {'url':'https://i.ytimg.com/vi/FFDl7fiJmdc/default.jpg'}
# ('Response:', 352)
# {'url':'https://i.ytimg.com/vi/FkErNWdE0W8/default.jpg'}
# ('Response:', 353)
# {'url':'https://i.ytimg.com/vi/125QT0SfhAw/default.jpg'}
# ('Response:', 354)
# {'url':'https://i.ytimg.com/vi/4ruY4idEkmY/default.jpg'}
# ('Response:', 355)
# {'url':'https://i.ytimg.com/vi/2YwZcC0q-1U/default.jpg'}
# ('Response:', 356)
# {'url':'https://i.ytimg.com/vi/evPD6n4FX3I/default.jpg'}
# ('Response:', 357)
# {'url':'https://i.ytimg.com/vi/Nk0TVlVaSFM/default.jpg'}
# ('Response:', 358)
# {'url':'https://i.ytimg.com/vi/9X9DJNN9DlI/default.jpg'}
# ('Response:', 359)
# {'url':'https://i.ytimg.com/vi/q9gY3za3GA4/default.jpg'}
# ('Response:', 360)
# Sleeping for 60 seconds
# ('Index Number', 360)
# ('Response:', 360)
# {'url':'https://i.ytimg.com/vi/A2yD6Vid6O8/default.jpg'}
# ('Response:', 361)
# {'url':'https://i.ytimg.com/vi/-O9H9aVTETg/default.jpg'}
# ('Response:', 362)
# {'url':'https://i.ytimg.com/vi/1z5vlNUuzdc/default.jpg'}
# ('Response:', 363)
# {'url':'https://i.ytimg.com/vi/tHyxaLWFkPA/default.jpg'}
# ('Response:', 364)
# {'url':'https://i.ytimg.com/vi/9Sh12fhMNHg/default.jpg'}
# ('Response:', 365)
# {'url':'https://i.ytimg.com/vi/ERtAmNchnFQ/default.jpg'}
# ('Response:', 366)
# {'url':'https://i.ytimg.com/vi/T5tCQeTT3d4/default.jpg'}
# ('Response:', 367)
# {'url':'https://i.ytimg.com/vi/NI2fabjbCkA/default.jpg'}
# ('Response:', 368)
# {'url':'https://i.ytimg.com/vi/nPxmVm3uvU8/default.jpg'}
# ('Response:', 369)
# {'url':'https://i.ytimg.com/vi/E99PgeH202o/default.jpg'}
# ('Response:', 370)
# {'url':'https://i.ytimg.com/vi/LAl95iEcJl4/default.jpg'}
# ('Response:', 371)
# {'url':'https://i.ytimg.com/vi/2SWx7EWKKUY/default.jpg'}
# ('Response:', 372)
# {'url':'https://i.ytimg.com/vi/HAZHNpaaQFU/default.jpg'}
# ('Response:', 373)
# {'url':'https://i.ytimg.com/vi/WSyYL72rShI/default.jpg'}
# ('Response:', 374)
# {'url':'https://i.ytimg.com/vi/If70HUxFlXE/default.jpg'}
# ('Response:', 375)
# {'url':'https://i.ytimg.com/vi/hqF7tZ-h87I/default.jpg'}
# ('Response:', 376)
# {'url':'https://i.ytimg.com/vi/Xc1VBw6P4lw/default.jpg'}
# ('Response:', 377)
# {'url':'https://i.ytimg.com/vi/W1xk4_nY5Bo/default.jpg'}
# ('Response:', 378)
# {'url':'https://i.ytimg.com/vi/Qp03uVChtnw/default.jpg'}
# ('Response:', 379)
# {'url':'https://i.ytimg.com/vi/0ZobkURemL4/default.jpg'}
# ('Response:', 380)
# Sleeping for 60 seconds
# ('Index Number', 380)
# ('Response:', 380)
# {'url':'https://i.ytimg.com/vi/B0gns621pAc/default.jpg'}
# ('Response:', 381)
# {'url':'https://i.ytimg.com/vi/X7u1wiA7Hao/default.jpg'}
# ('Response:', 382)
# {'url':'https://i.ytimg.com/vi/eRny27HNkLg/default.jpg'}
# ('Response:', 383)
# {'url':'https://i.ytimg.com/vi/GC8HLSx6JCA/default.jpg'}
# ('Response:', 384)
# {'url':'https://i.ytimg.com/vi/cH7YYKTDFcc/default.jpg'}
# ('Response:', 385)
# {'url':'https://i.ytimg.com/vi/3Q0vaxorkio/default.jpg'}
# ('Response:', 386)
# {'url':'https://i.ytimg.com/vi/qtCcV5TLXeI/default.jpg'}
# ('Response:', 387)
# {'url':'https://i.ytimg.com/vi/XWT6rBbZvcg/default.jpg'}
# ('Response:', 388)
# {'url':'https://i.ytimg.com/vi/XKpfNWj7Tg4/default.jpg'}
# ('Response:', 389)
# {'url':'https://i.ytimg.com/vi/L6fKlKAu1wE/default.jpg'}
# ('Response:', 390)
# {'url':'https://i.ytimg.com/vi/jc-YjrX4zJk/default.jpg'}
# ('Response:', 391)
# {'url':'https://i.ytimg.com/vi/pW2jbKXMlEk/default.jpg'}
# ('Response:', 392)
# {'url':'https://i.ytimg.com/vi/1332PtG2IG4/default.jpg'}
# ('Response:', 393)
# {'url':'https://i.ytimg.com/vi/3SkdubNg_so/default.jpg'}
# ('Response:', 394)
# {'url':'https://i.ytimg.com/vi/XGCpt6zjA4Q/default.jpg'}
# ('Response:', 395)
# {'url':'https://i.ytimg.com/vi/BJPaeIJxopE/default.jpg'}
# ('Response:', 396)
# {'url':'https://i.ytimg.com/vi/XECWbxD-CLc/default.jpg'}
# ('Response:', 397)
# {'url':'https://i.ytimg.com/vi/4LRD1DvcSFg/default.jpg'}
# ('Response:', 398)
# {'url':'https://i.ytimg.com/vi/MOhRYjdrA-E/default.jpg'}
# ('Response:', 399)
# {'url':'https://i.ytimg.com/vi/nRIawQ5vH1o/default.jpg'}
# ('Response:', 400)
# Sleeping for 60 seconds
# ('Index Number', 400)
# ('Response:', 400)
# {'url':'https://i.ytimg.com/vi/s6ThkfJuTyA/default.jpg'}
# ('Response:', 401)
# {'url':'https://i.ytimg.com/vi/1d80z3hBSh0/default.jpg'}
# ('Response:', 402)
# {'url':'https://i.ytimg.com/vi/dxq_dGgVviU/default.jpg'}
# ('Response:', 403)
# {'url':'https://i.ytimg.com/vi/H0vYEmvy10c/default.jpg'}
# ('Response:', 404)
# {'url':'https://i.ytimg.com/vi/3e4Gu1LyruE/default.jpg'}
# ('Response:', 405)
# {'url':'https://i.ytimg.com/vi/_34sIFBn07Q/default.jpg'}
# ('Response:', 406)
# {'url':'https://i.ytimg.com/vi/EJlmTu3HXKQ/default.jpg'}
# ('Response:', 407)
# {'url':'https://i.ytimg.com/vi/WaNb5HDniYE/default.jpg'}
# ('Response:', 408)
# {'url':'https://i.ytimg.com/vi/PHltEPVMiSo/default.jpg'}
# ('Response:', 409)
# {'url':'https://i.ytimg.com/vi/syRuxconkVE/default.jpg'}
# ('Response:', 410)
# {'url':'https://i.ytimg.com/vi/-KGqnKR1ino/default.jpg'}
# ('Response:', 411)
# {'url':'https://i.ytimg.com/vi/I2xicTAOjp8/default.jpg'}
# ('Response:', 412)
# {'url':'https://i.ytimg.com/vi/bhmeXGSKocY/default.jpg'}
# ('Response:', 413)
# {'url':'https://i.ytimg.com/vi/GCZxhJRjxGU/default.jpg'}
# ('Response:', 414)
# {'url':'https://i.ytimg.com/vi/W-NU8NUS8lI/default.jpg'}
# ('Response:', 415)
# {'url':'https://i.ytimg.com/vi/MAyjJwB7wtQ/default.jpg'}
# ('Response:', 416)
# {'url':'https://i.ytimg.com/vi/WpO5pgQwc5c/default.jpg'}
# ('Response:', 417)
# {'url':'https://i.ytimg.com/vi/3-vFqoMkIJ4/default.jpg'}
# ('Response:', 418)
# {'url':'https://i.ytimg.com/vi/mDN5DnMkSw4/default.jpg'}
# ('Response:', 419)
# {'url':'https://i.ytimg.com/vi/kzMBVcsMZzM/default.jpg'}
# ('Response:', 420)
# Sleeping for 60 seconds
# ('Index Number', 420)
# ('Response:', 420)
# {'url':'https://i.ytimg.com/vi/-wa7oICw4fg/default.jpg'}
# ('Response:', 421)
# {'url':'https://i.ytimg.com/vi/TWZT4nP0_sY/default.jpg'}
# ('Response:', 422)
# {'url':'https://i.ytimg.com/vi/U0RQ-RNjFrc/default.jpg'}
# ('Response:', 423)
# {'url':'https://i.ytimg.com/vi/CCC7eMDhxyw/default.jpg'}
# ('Response:', 424)
# {'url':'https://i.ytimg.com/vi/1ga-YDcZyqM/default.jpg'}
# ('Response:', 425)
# {'url':'https://i.ytimg.com/vi/uMBbOVZ-pPo/default.jpg'}
# ('Response:', 426)
# {'url':'https://i.ytimg.com/vi/_4E4HLvPoU8/default.jpg'}
# ('Response:', 427)
# {'url':'https://i.ytimg.com/vi/E8SBjjfEQxk/default.jpg'}
# ('Response:', 428)
# {'url':'https://i.ytimg.com/vi/BichUCZBDEc/default.jpg'}
# ('Response:', 429)
# {'url':'https://i.ytimg.com/vi/4pC9DKPGklo/default.jpg'}
# ('Response:', 430)
# {'url':'https://i.ytimg.com/vi/HOicVoj6ErA/default.jpg'}
# ('Response:', 431)
# {'url':'https://i.ytimg.com/vi/Zfvi-3sXLMk/default.jpg'}
# ('Response:', 432)
# {'url':'https://i.ytimg.com/vi/BYcci5a_3OE/default.jpg'}
# ('Response:', 433)
# {'url':'https://i.ytimg.com/vi/YHhGNIj1Kck/default.jpg'}
# ('Response:', 434)
# {'url':'https://i.ytimg.com/vi/FFSmvXkCGqc/default.jpg'}
# ('Response:', 435)
# {'url':'https://i.ytimg.com/vi/IJXNDTwHhc4/default.jpg'}
# ('Response:', 436)
# {'url':'https://i.ytimg.com/vi/5xLcsg-5Dw8/default.jpg'}
# ('Response:', 437)
# {'url':'https://i.ytimg.com/vi/WmAhOKKEUZI/default.jpg'}
# ('Response:', 438)
# {'url':'https://i.ytimg.com/vi/7GzOim7jHF4/default.jpg'}
# ('Response:', 439)
# {'url':'https://i.ytimg.com/vi/KJYXs-pWGn4/default.jpg'}
# ('Response:', 440)
# Sleeping for 60 seconds
# ('Index Number', 440)
# ('Response:', 440)
# {'url':'https://i.ytimg.com/vi/WQ-hjNf-3_c/default.jpg'}
# ('Response:', 441)
# {'url':'https://i.ytimg.com/vi/Rw48pWMs76o/default.jpg'}
# ('Response:', 442)
# {'url':'https://i.ytimg.com/vi/5BFtyoAU9Uc/default.jpg'}
# ('Response:', 443)
# {'url':'https://i.ytimg.com/vi/40LRbKzpx8E/default.jpg'}
# ('Response:', 444)
# {'url':'https://i.ytimg.com/vi/r2PPulgIJIg/default.jpg'}
# ('Response:', 445)
# {'url':'https://i.ytimg.com/vi/8p6nBNVbFus/default.jpg'}
# ('Response:', 446)
# {'url':'https://i.ytimg.com/vi/bxV8IMVAzzw/default.jpg'}
# ('Response:', 447)
# {'url':'https://i.ytimg.com/vi/3h6lab4GusU/default.jpg'}
# ('Response:', 448)
# {'url':'https://i.ytimg.com/vi/MYyOrOtcOz4/default.jpg'}
# ('Response:', 449)
# {'url':'https://i.ytimg.com/vi/_qKEzUb70RQ/default.jpg'}
# ('Response:', 450)
# {'url':'https://i.ytimg.com/vi/sKqfRkwHSNA/default.jpg'}
# ('Response:', 451)
# {'url':'https://i.ytimg.com/vi/x6rGpfYckAY/default.jpg'}
# ('Response:', 452)
# {'url':'https://i.ytimg.com/vi/BYXCXeO64go/default.jpg'}
# ('Response:', 453)
# {'url':'https://i.ytimg.com/vi/EfXnbMzGbWk/default.jpg'}
# ('Response:', 454)
# {'url':'https://i.ytimg.com/vi/ukchmgr-UWQ/default.jpg'}
# ('Response:', 455)
# {'url':'https://i.ytimg.com/vi/BJgLbN5UVMw/default.jpg'}
# ('Response:', 456)
# {'url':'https://i.ytimg.com/vi/q9dTRcMypNk/default.jpg'}
# ('Response:', 457)
# {'url':'https://i.ytimg.com/vi/NNLXkbiAX5s/default.jpg'}
# ('Response:', 458)
# {'url':'https://i.ytimg.com/vi/e8Dr-m9CmtM/default.jpg'}
# ('Response:', 459)
# {'url':'https://i.ytimg.com/vi/CASH77gPlY8/default.jpg'}
# ('Response:', 460)
# Sleeping for 60 seconds
# ('Index Number', 460)
# ('Response:', 460)
# {'url':'https://i.ytimg.com/vi/NSKhHGjV4XA/default.jpg'}
# ('Response:', 461)
# {'url':'https://i.ytimg.com/vi/GipI5VpBTGc/default.jpg'}
# ('Response:', 462)
# {'url':'https://i.ytimg.com/vi/-03E7HMN4og/default.jpg'}
# ('Response:', 463)
# {'url':'https://i.ytimg.com/vi/tR29jNdP1wU/default.jpg'}
# ('Response:', 464)
# {'url':'https://i.ytimg.com/vi/M9b_f-YmcHU/default.jpg'}
# ('Response:', 465)
# {'url':'https://i.ytimg.com/vi/_D4JnRJ3t6Q/default.jpg'}
# ('Response:', 466)
# {'url':'https://i.ytimg.com/vi/68UgLpWEa2k/default.jpg'}
# ('Response:', 467)
# {'url':'https://i.ytimg.com/vi/767km8OPGoI/default.jpg'}
# ('Response:', 468)
# {'url':'https://i.ytimg.com/vi/_QiKltZ9e9o/default.jpg'}
# ('Response:', 469)
# {'url':'https://i.ytimg.com/vi/s37AzS82Dnk/default.jpg'}
# ('Response:', 470)
# {'url':'https://i.ytimg.com/vi/ZUzZV6S6Ckw/default.jpg'}
# ('Response:', 471)
# {'url':'https://i.ytimg.com/vi/1dvyUkPRbWg/default.jpg'}
# ('Response:', 472)
# {'url':'https://i.ytimg.com/vi/1F4FtzOTnOA/default.jpg'}
# ('Response:', 473)
# {'url':'https://i.ytimg.com/vi/3DG6VyzXpLg/default.jpg'}
# ('Response:', 474)
# {'url':'https://i.ytimg.com/vi/HdUQdyZdWIQ/default.jpg'}
# ('Response:', 475)
# {'url':'https://i.ytimg.com/vi/zR6441fFLdo/default.jpg'}
# ('Response:', 476)
# {'url':'https://i.ytimg.com/vi/D5ZrnzJvK-M/default.jpg'}
# ('Response:', 477)
# {'url':'https://i.ytimg.com/vi/Makkvx7fKF8/default.jpg'}
# ('Response:', 478)
# {'url':'https://i.ytimg.com/vi/YiIkXk5XeGU/default.jpg'}
# ('Response:', 479)
# {'url':'https://i.ytimg.com/vi/gL_a-ziebC4/default.jpg'}
# ('Response:', 480)
# Sleeping for 60 seconds
# ('Index Number', 480)
# ('Response:', 480)
# {'url':'https://i.ytimg.com/vi/MSfCqoVkcFg/default.jpg'}
# ('Response:', 481)
# {'url':'https://i.ytimg.com/vi/blLpKkz90NI/default.jpg'}
# ('Response:', 482)
# {'url':'https://i.ytimg.com/vi/l5eISHaPNnc/default.jpg'}
# ('Response:', 483)
# {'url':'https://i.ytimg.com/vi/KJIMG5ByNi4/default.jpg'}
# ('Response:', 484)
# {'url':'https://i.ytimg.com/vi/kRPitkebtMQ/default.jpg'}
# ('Response:', 485)
# {'url':'https://i.ytimg.com/vi/gaSfYAm7VPM/default.jpg'}
# ('Response:', 486)
# {'url':'https://i.ytimg.com/vi/i7C--QsLU5g/default.jpg'}
# ('Response:', 487)
# {'url':'https://i.ytimg.com/vi/H_wyHwi8ppI/default.jpg'}
# ('Response:', 488)
# {'url':'https://i.ytimg.com/vi/34XRmd3a8_0/default.jpg'}
# ('Response:', 489)
# {'url':'https://i.ytimg.com/vi/S9ugmcS5R9E/default.jpg'}
# ('Response:', 490)
# {'url':'https://i.ytimg.com/vi/MbvPl4MCUys/default.jpg'}
# ('Response:', 491)
# {'url':'https://i.ytimg.com/vi/F3MiJymxQXA/default.jpg'}
# ('Response:', 492)
# {'url':'https://i.ytimg.com/vi/A97JrDdWXXg/default.jpg'}
# ('Response:', 493)
# {'url':'https://i.ytimg.com/vi/GI6_MCrDl6o/default.jpg'}
# ('Response:', 494)
# {'url':'https://i.ytimg.com/vi/1v4r9hht_K4/default.jpg'}
# ('Response:', 495)
# {'url':'https://i.ytimg.com/vi/AEaWu9q_Mwk/default.jpg'}
# ('Response:', 496)
# {'url':'https://i.ytimg.com/vi/xLyMYeBI--s/default.jpg'}
# ('Response:', 497)
# {'url':'https://i.ytimg.com/vi/hTbhmnXYC0U/default.jpg'}
# ('Response:', 498)
# {'url':'https://i.ytimg.com/vi/r_eSbz8M2vs/default.jpg'}
# ('Response:', 499)
# {'url':'https://i.ytimg.com/vi/HTc-VRRbl0E/default.jpg'}
# ('Response:', 500)
# Sleeping for 60 seconds
# ('Index Number', 500)
# ('Response:', 500)
# {'url':'https://i.ytimg.com/vi/LykRt1WGWUw/default.jpg'}
# ('Response:', 501)
# {'url':'https://i.ytimg.com/vi/KfJnXV1604g/default.jpg'}
# ('Response:', 502)
# {'url':'https://i.ytimg.com/vi/YHtKSGT_Crk/default.jpg'}
# ('Response:', 503)
# {'url':'https://i.ytimg.com/vi/EYN0-CPtVIc/default.jpg'}
# ('Response:', 504)
# {'url':'https://i.ytimg.com/vi/OjkjNrMWC7o/default.jpg'}
# ('Response:', 505)
# {'url':'https://i.ytimg.com/vi/EHt9TC1e8bA/default.jpg'}
# ('Response:', 506)
# {'url':'https://i.ytimg.com/vi/AVmGisDlOYc/default.jpg'}
# ('Response:', 507)
# {'url':'https://i.ytimg.com/vi/UWKDxlQfDI0/default.jpg'}
# ('Response:', 508)
# {'url':'https://i.ytimg.com/vi/Jsz-bT2y6rk/default.jpg'}
# ('Response:', 509)
# {'url':'https://i.ytimg.com/vi/N-8Jm7rXTQc/default.jpg'}
# ('Response:', 510)
# {'url':'https://i.ytimg.com/vi/Wdz-W-sS9nU/default.jpg'}
# ('Response:', 511)
# {'url':'https://i.ytimg.com/vi/n_-IM881amg/default.jpg'}
# ('Response:', 512)
# {'url':'https://i.ytimg.com/vi/8Zl83Gxx2ow/default.jpg'}
# ('Response:', 513)
# {'url':'https://i.ytimg.com/vi/NANfsr3Cge4/default.jpg'}
# ('Response:', 514)
# {'url':'https://i.ytimg.com/vi/61e9zZl7Rc4/default.jpg'}
# ('Response:', 515)
# {'url':'https://i.ytimg.com/vi/bnSooG_TuRI/default.jpg'}
# ('Response:', 516)
# {'url':'https://i.ytimg.com/vi/ALeSTRt6ehU/default.jpg'}
# ('Response:', 517)
# {'url':'https://i.ytimg.com/vi/A9w3rMtRyD0/default.jpg'}
# ('Response:', 518)
# {'url':'https://i.ytimg.com/vi/3-3l3qQg38I/default.jpg'}
# ('Response:', 519)
# {'url':'https://i.ytimg.com/vi/B1p6bbRTIlM/default.jpg'}
# ('Response:', 520)
# Sleeping for 60 seconds
# ('Index Number', 520)
# ('Response:', 520)
# {'url':'https://i.ytimg.com/vi/LmdwvIlE9Zg/default.jpg'}
# ('Response:', 521)
# {'url':'https://i.ytimg.com/vi/cONk0ybtX50/default.jpg'}
# ('Response:', 522)
# {'url':'https://i.ytimg.com/vi/Q3-IkGAbx14/default.jpg'}
# ('Response:', 523)
# {'url':'https://i.ytimg.com/vi/jVHaVeacKOY/default.jpg'}
# ('Response:', 524)
# {'url':'https://i.ytimg.com/vi/QURr_ujngCg/default.jpg'}
# ('Response:', 525)
# {'url':'https://i.ytimg.com/vi/F3TYGRsFWaQ/default.jpg'}
# ('Response:', 526)
# {'url':'https://i.ytimg.com/vi/7JDnQDTZCbc/default.jpg'}
# ('Response:', 527)
# {'url':'https://i.ytimg.com/vi/cEP1bGeXevs/default.jpg'}
# ('Response:', 528)
# {'url':'https://i.ytimg.com/vi/LR1kjlydMIY/default.jpg'}
# ('Response:', 529)
# {'url':'https://i.ytimg.com/vi/We9pxWchqw0/default.jpg'}
# ('Response:', 530)
# {'url':'https://i.ytimg.com/vi/Q6J5KMn7HPc/default.jpg'}
# ('Response:', 531)
# {'url':'https://i.ytimg.com/vi/V22VtTEWwtM/default.jpg'}
# ('Response:', 532)
# {'url':'https://i.ytimg.com/vi/KgHqmoYqUEo/default.jpg'}
# ('Response:', 533)
# {'url':'https://i.ytimg.com/vi/LPjIQcBMFzQ/default.jpg'}
# ('Response:', 534)
# {'url':'https://i.ytimg.com/vi/w5nvGjlDnHI/default.jpg'}
# ('Response:', 535)
# {'url':'https://i.ytimg.com/vi/CqX5Kj2E4n8/default.jpg'}
# ('Response:', 536)
# {'url':'https://i.ytimg.com/vi/rcU6bVfi2oc/default.jpg'}
# ('Response:', 537)
# {'url':'https://i.ytimg.com/vi/A-u-3oyblwY/default.jpg'}
# ('Response:', 538)
# {'url':'https://i.ytimg.com/vi/o0b5sstZ2wM/default.jpg'}
# ('Response:', 539)
# {'url':'https://i.ytimg.com/vi/XcXszuucND8/default.jpg'}
# ('Response:', 540)
# Sleeping for 60 seconds
# ('Index Number', 540)
# ('Response:', 540)
# {'url':'https://i.ytimg.com/vi/SRySDJZiNxU/default.jpg'}
# ('Response:', 541)
# {'url':'https://i.ytimg.com/vi/bCboX1rc4mU/default.jpg'}
# ('Response:', 542)
# {'url':'https://i.ytimg.com/vi/XieO76cuMr0/default.jpg'}
# ('Response:', 543)
# {'url':'https://i.ytimg.com/vi/z3sm6YgpJho/default.jpg'}
# ('Response:', 544)
# {'url':'https://i.ytimg.com/vi/wRlMI8Pd-CM/default.jpg'}
# ('Response:', 545)
# {'url':'https://i.ytimg.com/vi/-LnLTf1GU8Q/default.jpg'}
# ('Response:', 546)
# {'url':'https://i.ytimg.com/vi/56Y4fS-aNpk/default.jpg'}
# ('Response:', 547)
# {'url':'https://i.ytimg.com/vi/Nfw7gAtMIeI/default.jpg'}
# ('Response:', 548)
# {'url':'https://i.ytimg.com/vi/8m2clTjlobI/default.jpg'}
# ('Response:', 549)
# {'url':'https://i.ytimg.com/vi/5OBoQPMkHjs/default.jpg'}
# ('Response:', 550)
# {'url':'https://i.ytimg.com/vi/1xcgm30Ypnk/default.jpg'}
# ('Response:', 551)
# {'url':'https://i.ytimg.com/vi/EmtfrfgPKXc/default.jpg'}
# ('Response:', 552)
# {'url':'https://i.ytimg.com/vi/Fxcx4JWjLQU/default.jpg'}
# ('Response:', 553)
# {'url':'https://i.ytimg.com/vi/f-Hf83dymX0/default.jpg'}
# ('Response:', 554)
# {'url':'https://i.ytimg.com/vi/_-iH3OhIums/default.jpg'}
# ('Response:', 555)
# {'url':'https://i.ytimg.com/vi/QcQLObpoZwI/default.jpg'}
# ('Response:', 556)
# {'url':'https://i.ytimg.com/vi/JUV3_Smo9nI/default.jpg'}
# ('Response:', 557)
# {'url':'https://i.ytimg.com/vi/SKDzWxaC_U8/default.jpg'}
# ('Response:', 558)
# {'url':'https://i.ytimg.com/vi/NEJZc40Hyn4/default.jpg'}
# ('Response:', 559)
# {'url':'https://i.ytimg.com/vi/T2YfPMbsa28/default.jpg'}
# ('Response:', 560)
# Sleeping for 60 seconds
# ('Index Number', 560)
# ('Response:', 560)
# {'url':'https://i.ytimg.com/vi/bLwURF3AVxA/default.jpg'}
# ('Response:', 561)
# {'url':'https://i.ytimg.com/vi/FXJI2t2Mwqs/default.jpg'}
# ('Response:', 562)
# {'url':'https://i.ytimg.com/vi/kzg5rArKmqs/default.jpg'}
# ('Response:', 563)
# {'url':'https://i.ytimg.com/vi/b8qaNwn5B1g/default.jpg'}
# ('Response:', 564)
# {'url':'https://i.ytimg.com/vi/b7A-6IsjG_g/default.jpg'}
# ('Response:', 565)
# {'url':'https://i.ytimg.com/vi/42OJZ2S5V2M/default.jpg'}
# ('Response:', 566)
# {'url':'https://i.ytimg.com/vi/DtKcJau8_AM/default.jpg'}
# ('Response:', 567)
# {'url':'https://i.ytimg.com/vi/FsXMgP67vas/default.jpg'}
# ('Response:', 568)
# {'url':'https://i.ytimg.com/vi/PcRN2sfgFSc/default.jpg'}
# ('Response:', 569)
# {'url':'https://i.ytimg.com/vi/PdFqZvd6FxM/default.jpg'}
# ('Response:', 570)
# {'url':'https://i.ytimg.com/vi/U-lEp0Xx1ko/default.jpg'}
# ('Response:', 571)
# {'url':'https://i.ytimg.com/vi/X6cuNQ23dJI/default.jpg'}
# ('Response:', 572)
# {'url':'https://i.ytimg.com/vi/AGbhEEB8C68/default.jpg'}
# ('Response:', 573)
# {'url':'https://i.ytimg.com/vi/8BnkPdmfFP0/default.jpg'}
# ('Response:', 574)
# {'url':'https://i.ytimg.com/vi/qANffV4XGfM/default.jpg'}
# ('Response:', 575)
# {'url':'https://i.ytimg.com/vi/TRR18cVTl7w/default.jpg'}
# ('Response:', 576)
# {'url':'https://i.ytimg.com/vi/RKKloZ9RhaI/default.jpg'}
# ('Response:', 577)
# {'url':'https://i.ytimg.com/vi/oYicSjpxVjs/default.jpg'}
# ('Response:', 578)
# {'url':'https://i.ytimg.com/vi/e4r_5s4bYUY/default.jpg'}
# ('Response:', 579)
# {'url':'https://i.ytimg.com/vi/Li4g5p6s2eM/default.jpg'}
# ('Response:', 580)
# Sleeping for 60 seconds
# ('Index Number', 580)
# ('Response:', 580)
# {'url':'https://i.ytimg.com/vi/AttEmTdr2Ps/default.jpg'}
# ('Response:', 581)
# {'url':'https://i.ytimg.com/vi/dxBgfNNb4oY/default.jpg'}
# ('Response:', 582)
# {'url':'https://i.ytimg.com/vi/VNGw-ZdCijc/default.jpg'}
# ('Response:', 583)
# {'url':'https://i.ytimg.com/vi/88dXJg2LHAo/default.jpg'}
# ('Response:', 584)
# {'url':'https://i.ytimg.com/vi/YkcjdIp7Fwo/default.jpg'}
# ('Response:', 585)
# {'url':'https://i.ytimg.com/vi/oQLoxHSlSEQ/default.jpg'}
# ('Response:', 586)
# {'url':'https://i.ytimg.com/vi/G8IxhlL6jgE/default.jpg'}
# ('Response:', 587)
# {'url':'https://i.ytimg.com/vi/xrUOEwTDbqA/default.jpg'}
# ('Response:', 588)
# {'url':'https://i.ytimg.com/vi/3KZKUlGboWQ/default.jpg'}
# ('Response:', 589)
# {'url':'https://i.ytimg.com/vi/z3wI_M4J79A/default.jpg'}
# ('Response:', 590)
# {'url':'https://i.ytimg.com/vi/s7rN4vA1Nig/default.jpg'}
# ('Response:', 591)
# {'url':'https://i.ytimg.com/vi/bW9Y4S9dyeY/default.jpg'}
# ('Response:', 592)
# ...
# Sleeping for 60 seconds
# ('Index Number', 3800)
# ('Response:', 3800)
# {'url':'https://i.ytimg.com/vi/jNqCdgFCPwg/default.jpg'}
# ('Response:', 3801)
# {'url':'https://i.ytimg.com/vi/8YWQMqTmUGI/default.jpg'}
# ('Response:', 3802)
# {'url':'https://i.ytimg.com/vi/ttgGIvb07dc/default.jpg'}
# ('Response:', 3803)
# {'url':'https://i.ytimg.com/vi/qKz2L9hcU8k/default.jpg'}
# ('Response:', 3804)
# {'url':'https://i.ytimg.com/vi/FvrcUXv7XhA/default.jpg'}
# ('Response:', 3805)
# {'url':'https://i.ytimg.com/vi/cke_wXNiAmg/default.jpg'}
# ('Response:', 3806)
# {'url':'https://i.ytimg.com/vi/8yc8Ipcu9yo/default.jpg'}
# ('Response:', 3807)
# {'url':'https://i.ytimg.com/vi/M36KfbjgiUo/default.jpg'}
# ('Response:', 3808)
# {'url':'https://i.ytimg.com/vi/-4OyI8PIroQ/default.jpg'}
# ('Response:', 3809)
# {'url':'https://i.ytimg.com/vi/burcte76VZ4/default.jpg'}
# ('Response:', 3810)
# {'url':'https://i.ytimg.com/vi/nRt5FNyV7I4/default.jpg'}
# ('Response:', 3811)
# {'url':'https://i.ytimg.com/vi/5UW13aBQVoE/default.jpg'}
# ('Response:', 3812)
# {'url':'https://i.ytimg.com/vi/EMtpXz6r17o/default.jpg'}
# ('Response:', 3813)
# {'url':'https://i.ytimg.com/vi/SsISIrazDTk/default.jpg'}
# ('Response:', 3814)
# {'url':'https://i.ytimg.com/vi/i2OPewtMhB8/default.jpg'}
# ('Response:', 3815)
# {'url':'https://i.ytimg.com/vi/-IpC-x_zkOo/default.jpg'}
# ('Response:', 3816)
# {'url':'https://i.ytimg.com/vi/eQJvl4ITC1Q/default.jpg'}
# ('Response:', 3817)
# {'url':'https://i.ytimg.com/vi/NS2nGdL-h0g/default.jpg'}
# ('Response:', 3818)
# {'url':'https://i.ytimg.com/vi/4OnSfyKzvBU/default.jpg'}
# ('Response:', 3819)
# {'url':'https://i.ytimg.com/vi/uRNERosZGbE/default.jpg'}
# ('Response:', 3820)
# Sleeping for 60 seconds
# ('Index Number', 3820)
# ('Response:', 3820)
# {'url':'https://i.ytimg.com/vi/X49uT1yGYms/default.jpg'}
# ('Response:', 3821)
# {'url':'https://i.ytimg.com/vi/6wlK5kO7oiU/default.jpg'}
# ('Response:', 3822)
# {'url':'https://i.ytimg.com/vi/D67odtZnEZI/default.jpg'}
# ('Response:', 3823)
# {'url':'https://i.ytimg.com/vi/HRqU9y4JquU/default.jpg'}
# ('Response:', 3824)
# {'url':'https://i.ytimg.com/vi/XEXPjPJgXvw/default.jpg'}
# ('Response:', 3825)
# {'url':'https://i.ytimg.com/vi/w3emLcj7Jco/default.jpg'}
# ('Response:', 3826)
# {'url':'https://i.ytimg.com/vi/Fn2GIQlK5KQ/default.jpg'}
# ('Response:', 3827)
# {'url':'https://i.ytimg.com/vi/G_q2ETQBZuI/default.jpg'}
# ('Response:', 3828)
# {'url':'https://i.ytimg.com/vi/QNUKh55R1CM/default.jpg'}
# ('Response:', 3829)
# {'url':'https://i.ytimg.com/vi/57yGhNnhUEk/default.jpg'}
# ('Response:', 3830)
# {'url':'https://i.ytimg.com/vi/piACId3DGQA/default.jpg'}
# ('Response:', 3831)
# {'url':'https://i.ytimg.com/vi/vV1C8Ki_SOs/default.jpg'}
# ('Response:', 3832)
# {'url':'https://i.ytimg.com/vi/bBb7RJE6NB4/default.jpg'}
# ('Response:', 3833)
# {'url':'https://i.ytimg.com/vi/B6_R4pAuvDE/default.jpg'}
# ('Response:', 3834)
# {'url':'https://i.ytimg.com/vi/FBlJglygnmY/default.jpg'}
# ('Response:', 3835)
# {'url':'https://i.ytimg.com/vi/VI99_mdMDuM/default.jpg'}
# ('Response:', 3836)
# {'url':'https://i.ytimg.com/vi/w-SOEphl6GI/default.jpg'}
# ('Response:', 3837)
# {'url':'https://i.ytimg.com/vi/NieRd4IgPwg/default.jpg'}
# ('Response:', 3838)
# {'url':'https://i.ytimg.com/vi/U3C4DtdDxY4/default.jpg'}
# ('Response:', 3839)
# {'url':'https://i.ytimg.com/vi/HRULAkS_5uE/default.jpg'}
# ('Response:', 3840)
# Sleeping for 60 seconds
# ('Index Number', 3840)
# ('Response:', 3840)
# {'url':'https://i.ytimg.com/vi/cOE5wwMzG-w/default.jpg'}
# ('Response:', 3841)
# {'url':'https://i.ytimg.com/vi/KJ7ooXNsQos/default.jpg'}
# ('Response:', 3842)
# {'url':'https://i.ytimg.com/vi/ievko-gHHlA/default.jpg'}
# ('Response:', 3843)
# {'url':'https://i.ytimg.com/vi/bFZCwKIqjY4/default.jpg'}
# ('Response:', 3844)
# {'url':'https://i.ytimg.com/vi/48XWETeMY8Q/default.jpg'}
# ('Response:', 3845)
# {'url':'https://i.ytimg.com/vi/Z-34goPChL0/default.jpg'}
# ('Response:', 3846)
# {'url':'https://i.ytimg.com/vi/T4IWSlHicpA/default.jpg'}
# ('Response:', 3847)
# {'url':'https://i.ytimg.com/vi/HagyjOl7Vp0/default.jpg'}
# ('Response:', 3848)
# {'url':'https://i.ytimg.com/vi/ERZv5HvKQUs/default.jpg'}
# ('Response:', 3849)
# {'url':'https://i.ytimg.com/vi/k17-9kfYmWY/default.jpg'}
# ('Response:', 3850)
# {'url':'https://i.ytimg.com/vi/YCC7yGrJUV8/default.jpg'}
# ('Response:', 3851)
# {'url':'https://i.ytimg.com/vi/xMMjHBcsjH4/default.jpg'}
# ('Response:', 3852)
# {'url':'https://i.ytimg.com/vi/ZXSlJ9Ujw60/default.jpg'}
# ('Response:', 3853)
# {'url':'https://i.ytimg.com/vi/YIrZBc0Q6m8/default.jpg'}
# ('Response:', 3854)
# {'url':'https://i.ytimg.com/vi/22rp3_wrub4/default.jpg'}
# ('Response:', 3855)
# {'url':'https://i.ytimg.com/vi/vrJu7nnlldY/default.jpg'}
# ('Response:', 3856)
# {'url':'https://i.ytimg.com/vi/yODI00DTJlY/default.jpg'}
# ('Response:', 3857)
# {'url':'https://i.ytimg.com/vi/6Qc3fukxgE4/default.jpg'}
# ('Response:', 3858)
# {'url':'https://i.ytimg.com/vi/UZ-_f6rKviA/default.jpg'}
# ('Response:', 3859)
# {'url':'https://i.ytimg.com/vi/g7u1d5bEKsE/default.jpg'}
# ('Response:', 3860)
# Sleeping for 60 seconds
# ('Index Number', 3860)
# ('Response:', 3860)
# {'url':'https://i.ytimg.com/vi/YB8zHGyl6K4/default.jpg'}
# ('Response:', 3861)
# {'url':'https://i.ytimg.com/vi/xEPXryHy_6c/default.jpg'}
# ('Response:', 3862)
# {'url':'https://i.ytimg.com/vi/mW8zo_-RTZw/default.jpg'}
# ('Response:', 3863)
# {'url':'https://i.ytimg.com/vi/_0jF6VI9Qiw/default.jpg'}
# ('Response:', 3864)
# {'url':'https://i.ytimg.com/vi/TcapVN9Oplg/default.jpg'}
# ('Response:', 3865)
# {'url':'https://i.ytimg.com/vi/Lvexmepp7Wo/default.jpg'}
# ('Response:', 3866)
# {'url':'https://i.ytimg.com/vi/rGHqM3tuV-Q/default.jpg'}
# ('Response:', 3867)
# {'url':'https://i.ytimg.com/vi/NWumqWDzXMA/default.jpg'}
# ('Response:', 3868)
# {'url':'https://i.ytimg.com/vi/Oj2_nLM4ckM/default.jpg'}
# ('Response:', 3869)
# {'url':'https://i.ytimg.com/vi/-FnI6NZrRu0/default.jpg'}
# ('Response:', 3870)
# {'url':'https://i.ytimg.com/vi/t6U9ze0Gnoc/default.jpg'}
# ('Response:', 3871)
# {'url':'https://i.ytimg.com/vi/2ZRtflCvUWo/default.jpg'}
# ('Response:', 3872)
# {'url':'https://i.ytimg.com/vi/jyu0a1TbMXk/default.jpg'}
# ('Response:', 3873)
# {'url':'https://i.ytimg.com/vi/QfqtBQbMvFM/default.jpg'}
# ('Response:', 3874)
# {'url':'https://i.ytimg.com/vi/kFaggy1TjX8/default.jpg'}
# ('Response:', 3875)
# {'url':'https://i.ytimg.com/vi/LNmODv_BgHE/default.jpg'}
# ('Response:', 3876)
# {'url':'https://i.ytimg.com/vi/LFCLFSwiFfQ/default.jpg'}
# ('Response:', 3877)
# {'url':'https://i.ytimg.com/vi/UZaoBVS9AyU/default.jpg'}
# ('Response:', 3878)
# {'url':'https://i.ytimg.com/vi/nJTtGxjjtdo/default.jpg'}
# ('Response:', 3879)
# {'url':'https://i.ytimg.com/vi/WLoqazwTS0E/default.jpg'}
# ('Response:', 3880)
# Sleeping for 60 seconds
# ('Index Number', 3880)
# ('Response:', 3880)
# {'url':'https://i.ytimg.com/vi/HXzU_Nh9YYI/default.jpg'}
# ('Response:', 3881)
# {'url':'https://i.ytimg.com/vi/h4wgsaPaWM8/default.jpg'}
# ('Response:', 3882)
# {'url':'https://i.ytimg.com/vi/M5SPO_PrCxU/default.jpg'}
# ('Response:', 3883)
# {'url':'https://i.ytimg.com/vi/f3mVlKVMu-E/default.jpg'}
# ('Response:', 3884)
# {'url':'https://i.ytimg.com/vi/46-v38Wye5A/default.jpg'}
# ('Response:', 3885)
# {'url':'https://i.ytimg.com/vi/67BBwUeG370/default.jpg'}
# ('Response:', 3886)
# {'url':'https://i.ytimg.com/vi/rlBAI946aZE/default.jpg'}
# ('Response:', 3887)
# {'url':'https://i.ytimg.com/vi/Wzab1mtCEQY/default.jpg'}
# ('Response:', 3888)
# {'url':'https://i.ytimg.com/vi/PNH6OrE7Uw8/default.jpg'}
# ('Response:', 3889)
# {'url':'https://i.ytimg.com/vi/KfBwwI-r9fk/default.jpg'}
# ('Response:', 3890)
# {'url':'https://i.ytimg.com/vi/mhx98-nvWEY/default.jpg'}
# ('Response:', 3891)
# {'url':'https://i.ytimg.com/vi/bOTHJ85uKIc/default.jpg'}
# ('Response:', 3892)
# {'url':'https://i.ytimg.com/vi/5Apub3s2B8U/default.jpg'}
# ('Response:', 3893)
# {'url':'https://i.ytimg.com/vi/VQMeixMkIsM/default.jpg'}
# ('Response:', 3894)
# {'url':'https://i.ytimg.com/vi/K59IgN9Ix-c/default.jpg'}
# ('Response:', 3895)
# {'url':'https://i.ytimg.com/vi/82RsHsvqOJ8/default.jpg'}
# ('Response:', 3896)
# {'url':'https://i.ytimg.com/vi/zHgqzZbz3Og/default.jpg'}
# ('Response:', 3897)
# {'url':'https://i.ytimg.com/vi/X2yJoVyZ6hk/default.jpg'}
# ('Response:', 3898)
# {'url':'https://i.ytimg.com/vi/Q8u7hKfK8j4/default.jpg'}
# ('Response:', 3899)
# {'url':'https://i.ytimg.com/vi/NEyYh8pHO2Q/default.jpg'}
# ('Response:', 3900)
# Sleeping for 60 seconds
# ('Index Number', 3900)
# ('Response:', 3900)
# {'url':'https://i.ytimg.com/vi/2TIAk17Jw6w/default.jpg'}
# ('Response:', 3901)
# {'url':'https://i.ytimg.com/vi/9yFVtWWWcFg/default.jpg'}
# ('Response:', 3902)
# {'url':'https://i.ytimg.com/vi/ViMEuB-Uc70/default.jpg'}
# ('Response:', 3903)
# {'url':'https://i.ytimg.com/vi/E-RthjUtgg4/default.jpg'}
# ('Response:', 3904)
# {'url':'https://i.ytimg.com/vi/CMhsicMwMBc/default.jpg'}
# ('Response:', 3905)
# {'url':'https://i.ytimg.com/vi/M6alwq83LgA/default.jpg'}
# ('Response:', 3906)
# {'url':'https://i.ytimg.com/vi/NnWGT9tWU9I/default.jpg'}
# ('Response:', 3907)
# {'url':'https://i.ytimg.com/vi/DPvwNy8h4Dw/default.jpg'}
# ('Response:', 3908)
# {'url':'https://i.ytimg.com/vi/2KrhDq8on0E/default.jpg'}
# ('Response:', 3909)
# {'url':'https://i.ytimg.com/vi/UQ2wrHo4j9I/default.jpg'}
# ('Response:', 3910)
# {'url':'https://i.ytimg.com/vi/ilOoogrut4I/default.jpg'}
# ('Response:', 3911)
# {'url':'https://i.ytimg.com/vi/stuQR9GnZFo/default.jpg'}
# ('Response:', 3912)
# {'url':'https://i.ytimg.com/vi/q7d2kRG7Puw/default.jpg'}
# ('Response:', 3913)
# {'url':'https://i.ytimg.com/vi/4BKMVuszT8c/default.jpg'}
# ('Response:', 3914)
# {'url':'https://i.ytimg.com/vi/kkOBQXChdIU/default.jpg'}
# ('Response:', 3915)
# {'url':'https://i.ytimg.com/vi/cZhJPrEZGa4/default.jpg'}
# ('Response:', 3916)
# {'url':'https://i.ytimg.com/vi/AWtMTdwrn0Y/default.jpg'}
# ('Response:', 3917)
# {'url':'https://i.ytimg.com/vi/6pr59fHKuzY/default.jpg'}
# ('Response:', 3918)
# {'url':'https://i.ytimg.com/vi/a9gz2tnud94/default.jpg'}
# ('Response:', 3919)
# {'url':'https://i.ytimg.com/vi/whsdWmXpJGs/default.jpg'}
# ('Response:', 3920)
# Sleeping for 60 seconds
# ('Index Number', 3920)
# ('Response:', 3920)
# {'url':'https://i.ytimg.com/vi/wNaSt-Nuezo/default.jpg'}
# ('Response:', 3921)
# {'url':'https://i.ytimg.com/vi/-BVtAItdWa0/default.jpg'}
# ('Response:', 3922)
# {'url':'https://i.ytimg.com/vi/6VeoxLm-1fE/default.jpg'}
# ('Response:', 3923)
# {'url':'https://i.ytimg.com/vi/8ZwPqFIQH7E/default.jpg'}
# ('Response:', 3924)
# {'url':'https://i.ytimg.com/vi/56anyZ-iXc4/default.jpg'}
# ('Response:', 3925)
# {'url':'https://i.ytimg.com/vi/3P6fHGPkb_w/default.jpg'}
# ('Response:', 3926)
# {'url':'https://i.ytimg.com/vi/WXtoZ9ZN6Rs/default.jpg'}
# ('Response:', 3927)
# {'url':'https://i.ytimg.com/vi/cMVQG6fMagM/default.jpg'}
# ('Response:', 3928)
# {'url':'https://i.ytimg.com/vi/W6M1FeL1jnU/default.jpg'}
# ('Response:', 3929)
# {'url':'https://i.ytimg.com/vi/iz5FLUg58AA/default.jpg'}
# ('Response:', 3930)
# {'url':'https://i.ytimg.com/vi/UGbyWg_IkJ8/default.jpg'}
# ('Response:', 3931)
# {'url':'https://i.ytimg.com/vi/VNVgxYLfSSU/default.jpg'}
# ('Response:', 3932)
# {'url':'https://i.ytimg.com/vi/95uWSsgTkzE/default.jpg'}
# ('Response:', 3933)
# {'url':'https://i.ytimg.com/vi/TKqeuw-ww6k/default.jpg'}
# ('Response:', 3934)
# {'url':'https://i.ytimg.com/vi/jZMLl0Ou-dw/default.jpg'}
# ('Response:', 3935)
# {'url':'https://i.ytimg.com/vi/Ip4zGULDwok/default.jpg'}
# ('Response:', 3936)
# {'url':'https://i.ytimg.com/vi/QI06vTOfIdc/default.jpg'}
# ('Response:', 3937)
# {'url':'https://i.ytimg.com/vi/NWpg7tNul20/default.jpg'}
# ('Response:', 3938)
# {'url':'https://i.ytimg.com/vi/HyIlloPHouQ/default.jpg'}
# ('Response:', 3939)
# {'url':'https://i.ytimg.com/vi/K3P1-326ORw/default.jpg'}
# ('Response:', 3940)
# Sleeping for 60 seconds
# ('Index Number', 3940)
# ('Response:', 3940)
# {'url':'https://i.ytimg.com/vi/zfm8VOkYqao/default.jpg'}
# ('Response:', 3941)
# {'url':'https://i.ytimg.com/vi/P70F8jpfZHI/default.jpg'}
# ('Response:', 3942)
# {'url':'https://i.ytimg.com/vi/WJ9MU7iAgVk/default.jpg'}
# ('Response:', 3943)
# {'url':'https://i.ytimg.com/vi/aWi3DHdV6mw/default.jpg'}
# ('Response:', 3944)
# {'url':'https://i.ytimg.com/vi/vNVqbamPp4E/default.jpg'}
# ('Response:', 3945)
# {'url':'https://i.ytimg.com/vi/Sr2bvMu1b5M/default.jpg'}
# ('Response:', 3946)
# {'url':'https://i.ytimg.com/vi/5r2te_7cgG0/default.jpg'}
# ('Response:', 3947)
# {'url':'https://i.ytimg.com/vi/AGY5mkWwT2o/default.jpg'}
# ('Response:', 3948)
# {'url':'https://i.ytimg.com/vi/9R8OhS00rro/default.jpg'}
# ('Response:', 3949)
# {'url':'https://i.ytimg.com/vi/sDaPcrB_IIc/default.jpg'}
# ('Response:', 3950)
# {'url':'https://i.ytimg.com/vi/hkUX6QIgwHg/default.jpg'}
# ('Response:', 3951)
# {'url':'https://i.ytimg.com/vi/qGwWJJVozE0/default.jpg'}
# ('Response:', 3952)
# {'url':'https://i.ytimg.com/vi/i3CDvy3RmDo/default.jpg'}
# ('Response:', 3953)
# {'url':'https://i.ytimg.com/vi/ZdnyvvAzTAY/default.jpg'}
# ('Response:', 3954)
# {'url':'https://i.ytimg.com/vi/OWh4_PEDlMA/default.jpg'}
# ('Response:', 3955)
# {'url':'https://i.ytimg.com/vi/3VIy9TwS_Sg/default.jpg'}
# ('Response:', 3956)
# {'url':'https://i.ytimg.com/vi/xFP-JnQfd28/default.jpg'}
# ('Response:', 3957)
# {'url':'https://i.ytimg.com/vi/SkWRx3R_wzA/default.jpg'}
# ('Response:', 3958)
# {'url':'https://i.ytimg.com/vi/GZBsYSnfZ_Y/default.jpg'}
# ('Response:', 3959)
# {'url':'https://i.ytimg.com/vi/PDGLBLdPTxo/default.jpg'}
# ('Response:', 3960)
# Sleeping for 60 seconds
# ('Index Number', 3960)
# ('Response:', 3960)
# {'url':'https://i.ytimg.com/vi/KXjccoB1X4Q/default.jpg'}
# ('Response:', 3961)
# {'url':'https://i.ytimg.com/vi/ZzokCnu1-5Q/default.jpg'}
# ('Response:', 3962)
# {'url':'https://i.ytimg.com/vi/OdbddSd62OM/default.jpg'}
# ('Response:', 3963)
# {'url':'https://i.ytimg.com/vi/-Ar0iyfDQ5M/default.jpg'}
# ('Response:', 3964)
# {'url':'https://i.ytimg.com/vi/5O0XVBuPgbA/default.jpg'}
# ('Response:', 3965)
# {'url':'https://i.ytimg.com/vi/02PjyIniUYo/default.jpg'}
# ('Response:', 3966)
# {'url':'https://i.ytimg.com/vi/83JU-t0ebl8/default.jpg'}
# ('Response:', 3967)
# {'url':'https://i.ytimg.com/vi/L6vDGnJiVw4/default.jpg'}
# ('Response:', 3968)
# {'url':'https://i.ytimg.com/vi/eOwFBdglLxs/default.jpg'}
# ('Response:', 3969)
# {'url':'https://i.ytimg.com/vi/r1pl1CLLwZc/default.jpg'}
# ('Response:', 3970)
# {'url':'https://i.ytimg.com/vi/t4si54rxtW8/default.jpg'}
# ('Response:', 3971)
# {'url':'https://i.ytimg.com/vi/o81Q-a3ms6A/default.jpg'}
# ('Response:', 3972)
# {'url':'https://i.ytimg.com/vi/27Z1lD5Xlto/default.jpg'}
# ('Response:', 3973)
# {'url':'https://i.ytimg.com/vi/DGZUHRGeT8g/default.jpg'}
# ('Response:', 3974)
# {'url':'https://i.ytimg.com/vi/YDdNgOwXjd4/default.jpg'}
# ('Response:', 3975)
# {'url':'https://i.ytimg.com/vi/qhIEV1m3S14/default.jpg'}
# ('Response:', 3976)
# {'url':'https://i.ytimg.com/vi/QBxlB1-UJ2s/default.jpg'}
# ('Response:', 3977)
# {'url':'https://i.ytimg.com/vi/iN3HTjIHsu4/default.jpg'}
# ('Response:', 3978)
# {'url':'https://i.ytimg.com/vi/cHpacaPm7aQ/default.jpg'}
# ('Response:', 3979)
# {'url':'https://i.ytimg.com/vi/0bciNGdlyTc/default.jpg'}
# ('Response:', 3980)
# Sleeping for 60 seconds
# ('Index Number', 3980)
# ('Response:', 3980)
# {'url':'https://i.ytimg.com/vi/aN0-pCfR50c/default.jpg'}
# ('Response:', 3981)
# {'url':'https://i.ytimg.com/vi/kr92rp0Kdfg/default.jpg'}
# ('Response:', 3982)
# {'url':'https://i.ytimg.com/vi/WlU7Z-WxSmU/default.jpg'}
# ('Response:', 3983)
# {'url':'https://i.ytimg.com/vi/ZVjZU-8TiSA/default.jpg'}
# ('Response:', 3984)
# {'url':'https://i.ytimg.com/vi/NcotYHE8OOM/default.jpg'}
# ('Response:', 3985)
# {'url':'https://i.ytimg.com/vi/YG2dxkDIW_I/default.jpg'}
# ('Response:', 3986)
# {'url':'https://i.ytimg.com/vi/I8wxSl3VWw0/default.jpg'}
# ('Response:', 3987)
# {'url':'https://i.ytimg.com/vi/_DPb2SKCG_E/default.jpg'}
# ('Response:', 3988)
# {'url':'https://i.ytimg.com/vi/1UIY8WeBvIU/default.jpg'}
# ('Response:', 3989)
# {'url':'https://i.ytimg.com/vi/c0_r69WPzJ4/default.jpg'}
# ('Response:', 3990)
# {'url':'https://i.ytimg.com/vi/NkgNK-vNyoQ/default.jpg'}
# ('Response:', 3991)
# {'url':'https://i.ytimg.com/vi/LGGRunOErN4/default.jpg'}
# ('Response:', 3992)
# {'url':'https://i.ytimg.com/vi/wBUhRpm2uG8/default.jpg'}
# ('Response:', 3993)
# {'url':'https://i.ytimg.com/vi/JfV8MY6LmLQ/default.jpg'}
# ('Response:', 3994)
# {'url':'https://i.ytimg.com/vi/H-FPRAa-new/default.jpg'}
# ('Response:', 3995)
# {'url':'https://i.ytimg.com/vi/2Gdx-zecxKI/default.jpg'}
# ('Response:', 3996)
# {'url':'https://i.ytimg.com/vi/feSEkHnTMgU/default.jpg'}
# ('Response:', 3997)
# {'url':'https://i.ytimg.com/vi/2M0MpGOX-58/default.jpg'}
# ('Response:', 3998)
# {'url':'https://i.ytimg.com/vi/SHe61P-SvOg/default.jpg'}
# ('Response:', 3999)

# %%
ROOT_DIR = os.path.dirname(os.path.realpath('__file__'))
DATA_PATH = os.path.join(ROOT_DIR, '..', 'data')


script_path = os.path.join(DATA_PATH, 'subsetwithTextClass.csv')
df.to_csv(script_path,index = False)

# %%
parsed
# Out:
# {u'message': u'Rate limit is exceeded. Try again in 40 seconds.',
#  u'statusCode': 429}

# %%
df = df[4000:8000]
df.shape[0]
df['ImageText'] = ''
df['ContainsText'] = ''

# %%
########### Python 2.7 #############
import httplib, urllib, base64, json, re, time

###############################################
#### Update or verify the following values. ###
###############################################

# Replace the subscription_key string value with your valid subscription key.
subscription_key = 'd40dd6c7f8544620af87278bd0ca3636'

# Replace or verify the region.
#
# You must use the same region in your REST API call as you used to obtain your subscription keys.
# For example, if you obtained your subscription keys from the westus region, replace
# "westcentralus" in the URI below with "westus".
#
# NOTE: Free trial subscription keys are generated in the westcentralus region, so if you are using
# a free trial subscription key, you should not need to change this region.
uri_base = 'westcentralus.api.cognitive.microsoft.com'

headers = {
    # Request headers.
    'Content-Type': 'application/json',
    'Ocp-Apim-Subscription-Key': subscription_key,
}

params = urllib.urlencode({
    # Request parameters. The language setting "unk" means automatically detect the language.
    'language': 'unk',
    'detectOrientation ': 'true',
})


for index, row in df.iterrows():
    link = re.findall(r"'(.*?)'",df['Thumbnail Default'][index])[0]  
    # The URL of a JPEG image containing text.
    body = "{'url':" + "'" + link + "'" + "}"
    print body
    try:
        # Execute the REST API call and get the response.
        conn = httplib.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
        conn.request("POST", "/vision/v1.0/ocr?%s" % params, body, headers)
        response = conn.getresponse()
        data = response.read()

        # 'data' contains the JSON data. The following formats the JSON data for display.
        parsed = json.loads(data)
        print ("Response:", index)
        #print (json.dumps(parsed, sort_keys=True, indent=2))

        df['ImageText'][index] = parsed 
        df['ContainsText'][index] = str(parsed['orientation'] != 'NotDetected')
        
    except Exception as e:
        
        
        print("Sleeping for 60 seconds")
        print("Index Number",index)
        time.sleep(61)          
        
        # Execute the REST API call and get the response.
        conn = httplib.HTTPSConnection('westcentralus.api.cognitive.microsoft.com')
        conn.request("POST", "/vision/v1.0/ocr?%s" % params, body, headers)
        response = conn.getresponse()
        data = response.read()

        # 'data' contains the JSON data. The following formats the JSON data for display.
        parsed = json.loads(data)
        print ("Response:", index)
        #print (json.dumps(parsed, sort_keys=True, indent=2))

        df['ImageText'][index] = parsed 
        df['ContainsText'][index] = str(parsed['orientation'] != 'NotDetected')
        
conn.close()
